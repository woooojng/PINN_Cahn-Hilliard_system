# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import torch 
import numpy as np
from torch.autograd import Variable
import time
import shutil
import os
from datetime import datetime
currentDateTime = datetime.now()
print("Date of Today : ", currentDateTime.month, " /", currentDateTime.day, "\nHour : ", currentDateTime.hour) 

#Date of Today
ctime = f"{currentDateTime.month}_{currentDateTime.day}_{currentDateTime.hour}h"
#torch.autograd.detect_anomaly(check_nan=True)

#Call model of layers and its forward step
from Forward_with_Layer_Setting import Net

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#Call training functions of Loss functions
from NSpde_loss import lossNSpde
from BoundaryLoss import lossBdry
from InitialConditionLoss import lossIC
from Energy_Loss import Energy_loss
from Mass_Loss import Mass_loss


def create_network(load, loadfile):
    
    net = Net()
    net = net.to(device)


    #attempt to initial parameters if they exists
    if load == True:
        try:
            net.load_state_dict(torch.load(loadfile, map_location=torch.device(device)))
        except:
            print("\nLoading file was failed\n") #pass
        else:
            print("\nLoading file was completed\n")
    
    global epsilon #used to track loss
    epsilon = []
    global a_set #used to track a
    a_set = []
    global b_set #used to track b
    b_set = []
    
    a = 100
    b = 100
    
    print('Training PDE')
    start = time.time() #begin tracking computational time
    
    computation_time_vec = [0, 0, 0, 0] #used to record training time
    for i in range(4):
        #Set loop to optimize in progressively smaller learning rates
        if i == 0:
            #First loop uses progressively increasing time intervals
            print('\n\nExecuting Pass 1\n')
            time_slices = np.array([ 1])# .1,  .3, .6,
            iterations = 30000
            learning_rate = 10**-3    
        elif i == 1:
            print('\n\nExecuting Pass 2\n')
            time_slices = [time_slices[-1]]
            #time_slices = np.array([10])
            iterations = 30000
            learning_rate = 10**-3
        elif i == 2:
            print('\n\nExecuting Pass 3\n')
            time_slices = [time_slices[-1]]
            iterations = 30000
            learning_rate = 10**-4
        elif i ==3:
            print('\n\nExecuting Pass 4\n')
            iterations = 30000
            learning_rate = 10**-4
        
        training_loop(net, time_slices, iterations, learning_rate, IC_coefficient = 1, record_loss = 100, print_loss = 500, a = a, b = b)
        
        
        torch.save(net.state_dict(), f"{ctime}NNlayers_NSCH_{i}.pt")
        np.savetxt('epsilon.txt', epsilon)
        np.savetxt('a_set.txt', a_set)
        np.savetxt('b_set.txt', b_set)
        computation_time_vec[i] = time.time()

    np.savetxt('epsilon.txt', epsilon)

    print("Total Time:\t", computation_time_vec[-1]-start, '\nPass 1 Time:\t', computation_time_vec[0]-start, '\nPass 2 Time:\t', computation_time_vec[1]-computation_time_vec[0], '\nPass 3 Time:\t', computation_time_vec[2]-computation_time_vec[1], '\nPass 4 Time:\t', computation_time_vec[3]-computation_time_vec[2])
'''
def exponential_time_sample(collocation, t_l, t_u, r):
    t_pre = np.random.uniform(1,np.exp(10/4), size=(collocation, 1))
    
    #t = -np.log(1-t_pre+t_pre*np.exp(-r*(t_u-t_l)))/r
    #10/5 t = 5*np.tan(np.pi*t_pre/2)+5 ; -0.5,0.5,
    t = 4 * np.log(t_pre)
    return t 

def pdf_cust(net, x):
    # (a)
    # V = 1.5
    # pdf = 4/(x * np.sqrt(V*2*np.pi))*np.exp(-(np.log(x/4))**2/(2*V))
    
    #min_cust, max_cust = 0, 0.69522
    
    # (b)
    # x = torch.tensor(x).detach()
    # x = torch.reshape(x, (1, 1)).detach()
    # mass = net.mass(x)
    # mass = mass.detach().numpy()
    
    # pdf = np.exp(5*np.absolute(mass))
    
    # (c) not recommend
    # pdf = 1/(1+np.exp(-20 * x+10))+.03
    #max_cust = 1.03 #3.4038987  # maximum of pdf by pdf at pt file points at beginning
    
    # (d)
    V = 1.5
    pdf = 20/(x * np.sqrt(V*2*np.pi))*np.exp(-(np.log(x/20))**2/(2*2*V))
    
    min_cust, max_cust = 0, 1.459849
    return (pdf)/(max_cust)

def random_pdf_cust(net, collocation, t_l, t_u):
    t_pts=np.array([])
    
    while len(t_pts)< collocation:
        t =np.random.uniform(low=t_l+.000001,high=t_u) #
        
        density = pdf_cust(net, t)
        u = np.random.uniform(low=0,high=1)
        #print(density)
        #print(u)
        assert density>=0 and density<=1
        if u <=density:
            t_pts = np.append(t_pts, t)
            #print(t_pts)
    t_pts = np.resize(t_pts, (collocation,1))
    return t_pts
'''

def SpatialTrainPts(net, Domain_collocation, Bdry_collocation, IC_collocation, t_l, t_f): # Mass_collocation, Energy_collocation,
    #Set of all the recorded xy variables as base data for chasing during training
    
    # Domain boundary in the range [0, 1]x[0, 2] and time in [0, 1].
    x_l = net.x_l
    x_u = net.x_u
    y_l = net.y_l
    y_u = net.y_u
    z_l = net.z_l
    z_u = net.z_u

    #Pick NSpde Condition Training Random Points in Numpy
    x_domain = np.random.uniform(low= x_l, high=x_u, size=(Domain_collocation, 1))
    #x_domain = np.random.uniform(low= -1, high=1, size=(Domain_collocation, 1))
    y_domain = np.random.uniform(low= y_l, high=y_u, size=(Domain_collocation, 1)) 
    #y_domain = np.random.uniform(low= -1, high=1, size=(Domain_collocation, 1)) 
    z_domain = np.random.uniform(low= z_l, high=z_u, size=(Domain_collocation, 1)) 
    
    #10.11
    t_domain = np.random.uniform(low= t_l, high=t_f, size=(Domain_collocation, 1)) 
    #t_domain = exponential_time_sample(Domain_collocation, t_l, t_f, 0.2)
    
    
    #10.9 t_domain = random_pdf_cust(Domain_collocation, t_l, t_f)
    # t_domain = random_pdf_cust(net, Domain_collocation, t_l, t_f)
    
    #x_domain = (x_domain**3+1)/2
    #y_domain = (y_domain**3+1)/2
    
    #Move to pytorch tensors
    x_domain = Variable(torch.from_numpy(x_domain).float(), requires_grad=True).to(device)
    y_domain = Variable(torch.from_numpy(y_domain).float(), requires_grad=True).to(device)
    z_domain = Variable(torch.from_numpy(z_domain).float(), requires_grad=True).to(device)

    t_domain = Variable(torch.from_numpy(t_domain).float(), requires_grad=True).to(device)
    
    
    #Pick IC Training t starting points to make tensor
    x_IC = np.random.uniform(low= x_l, high=x_u, size=(IC_collocation, 1)) 
    y_IC = np.random.uniform(low= y_l, high=y_u, size=(IC_collocation, 1)) 
    z_IC = np.random.uniform(low= z_l, high=z_u, size=(IC_collocation, 1)) 

    t_IC = np.random.uniform(low= t_l, high=t_l, size=(IC_collocation, 1)) 
    
    '''
    x_IC = np.linspace( x_l, x_u, num=IC_collocation).reshape((IC_collocation, 1)) #linspace
    y_IC = np.linspace(y_l, y_u, num=IC_collocation).reshape((IC_collocation, 1))
    z_IC = np.linspace(z_l, z_u, num=IC_collocation).reshape((IC_collocation, 1))

    t_IC =  np.linspace(t_l, t_l, num=IC_collocation).reshape((IC_collocation, 1))
    '''
    x_IC = Variable(torch.from_numpy(x_IC).float(), requires_grad=True).to(device)
    y_IC = Variable(torch.from_numpy(y_IC).float(), requires_grad=True).to(device)
    z_IC = Variable(torch.from_numpy(z_IC).float(), requires_grad=True).to(device)

    t_IC = Variable(torch.from_numpy(t_IC).float(), requires_grad=True).to(device)
    
    #Pick BC Training Random Points in Numpy 
    x_Bdry = np.random.uniform(low=x_l, high=x_u, size=(Bdry_collocation,1))
    y_Bdry = np.random.uniform(low=y_l, high=y_u, size=(Bdry_collocation,1))
    z_Bdry = np.random.uniform(low=z_l, high=z_u, size=(Bdry_collocation,1))

    t_Bdry = np.random.uniform(low=t_l, high=t_f, size=(Bdry_collocation,1))      
    
    '''
    x_Bdry = np.linspace( x_l,  x_u,num=Bdry_collocation).reshape( (Bdry_collocation,1))
    y_Bdry = np.linspace( y_l, y_u, num=Bdry_collocation).reshape( (Bdry_collocation,1))
    z_Bdry = np.linspace( z_l,  z_u, num=Bdry_collocation).reshape( (Bdry_collocation,1))

    t_Bdry = np.linspace(t_l, t_f,num=Bdry_collocation).reshape( (Bdry_collocation,1))      
    '''
    #Move to pytorch tensors
    x_Bdry= Variable(torch.from_numpy(x_Bdry).float(), requires_grad=True).to(device)
    y_Bdry = Variable(torch.from_numpy(y_Bdry).float(), requires_grad=True).to(device)
    z_Bdry = Variable(torch.from_numpy(z_Bdry).float(), requires_grad=True).to(device)

    t_Bdry = Variable(torch.from_numpy(t_Bdry).float(), requires_grad=True).to(device)
         
    return x_domain, y_domain, z_domain, t_domain, x_IC, y_IC, z_IC, t_IC, x_Bdry, y_Bdry, z_Bdry, t_Bdry #, t_mass, t_energy

'''
def twoDimTrainPts_IC_Only(net, IC_collocation):
    #Set of all the recorded xy variables as base data for chasing during training
    
    # Domain boundary in the range [0, 1]x[0, 2] and time in [0, 1].
    x_l = net.x1_l
    x_u = net.x1_u
    y_l = net.x2_l
    y_u = net.x2_u
    
    #Pick IC Training t starting points to make tensor
    x_IC = np.linspace(low= x_l, high=x_u, size=(IC_collocation, 1)) 
    y_IC = np.random.uniform(low= y_l, high=y_u, size=(IC_collocation, 1)) 
    
    x_IC = Variable(torch.from_numpy(x_IC).float(), requires_grad=True).to(device)
    y_IC = Variable(torch.from_numpy(y_IC).float(), requires_grad=True).to(device)
    t_IC = Variable(torch.zeros_like(x_IC), requires_grad=True).to(device)
            
    return x_IC, y_IC, t_IC
'''    
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
'''
def Create_IC_Parameters(Net, iterations, IC_collocation, learning_rate, filename, record_loss, print_loss):
    ICnet = Net.to(device)
    
    IC_loss = IC_Only_training(ICnet, iterations, IC_collocation, learning_rate, record_loss, print_loss)
    
    torch.save(ICnet.state_dict(), filename)
    
    return IC_loss

def IC_Only_training(net, iterations, IC_collocation, learning_rate, record_loss, print_loss):

    #learning rate update
    for g in net.optimizer.param_groups:
        g['lr'] = learning_rate
    
    #training loop
    epsilon_IC = [] #placeholder to track decreasing loss
    for epoch in range(1, iterations+1):
    
        # Resetting gradients to zero
        lbfgs.zero_grad() #net.optimizer.zero_grad()
           
        #get sample points
        x_IC, y_IC, t_IC = twoDimTrainPts_IC_Only(net, IC_collocation)
        
        #Loss based on Initial Condition
        loss = lossIC(net, x_IC, y_IC, t_IC)
           
        loss.backward()
        
        # Gradient Norm Clipping
        torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm= 1, norm_type=2, error_if_nonfinite=True)

        #Gradient Value Clipping
        #nn.utils.clip_grad_value_(net.parameters(), clip_value=1.0)
        
        lbfgs.optimizer.step() #net.optimizer.step()
           
        #Print Loss every 1000 Epochs
        with torch.autograd.no_grad():
            
            if epoch%record_loss == 0:
                epsilon_IC = np.append(epsilon_IC, loss.cpu().detach().numpy())
            if epoch%print_loss == 0:
                print("Iteration:", epoch, "IC Loss:", loss.item())
    
    np.savetxt('epsilon_IC.txt', epsilon_IC)
    
    return loss.item()

'''
def training_loop(net, time_slices, iterations, learning_rate, IC_coefficient, record_loss, print_loss,a,b):
    #Main training loop function
    global epsilon #used to track and record loss
    global b_set
    global a_set
    #Set numbers of collocation points
    Domain_collocation = 10000 #3d sample points
    Bdry_collocation = 6*31**2 #2d sample points
    IC_collocation = 6*31**2 #2d sample points
    #Mass_collocation = 102
    #Energy_collocation = 103
    lamba = .1
    
    #update the learning rate as desired
    for g in net.optimizer.param_groups:
        g['lr'] = learning_rate
    
    #Iterate over time slices
    for final_time in time_slices:
        min_loss = 50
        min_mse_NS = 50
        min_mse_IC = 1
        
        
        #Print relevant hyperparameters (final sampling time and learning rate)
        with torch.autograd.no_grad():
            print("Current Final Time:", final_time, "Current Learning Rate: ", get_lr(net.optimizer))  
        
        #Set lower bound of time
        t_l = 0
        
        #Begin Iterative Procedure
        for epoch in range(1, iterations+1):
            
            #Choose Sample Points #, t_mass, t_energy
            x_domain, y_domain, z_domain, t_domain, x_IC, y_IC, z_IC, t_IC, x_Bdry, y_Bdry, z_Bdry, t_Bdry = SpatialTrainPts(net, Domain_collocation, Bdry_collocation, IC_collocation, t_l, final_time)
            
            # Resetting gradients to zero
            net.optimizer.zero_grad() #net.optimizer.zero_grad()
            '''
            ##################################################################################
            for param in net.parameters():
                print(param)
            '''
            #Loss based on Initial Condition
            mse_IC = lossIC(net, x_IC, y_IC, z_IC, t_IC)
            
            #Loss based on Boundary Condition (Containing No-Slip and Free-slip)
            boundary_domain_loss = lossBdry(net, x_Bdry, y_Bdry, z_Bdry, t_Bdry)
            mse_BC = boundary_domain_loss 
            
            #Loss based on PDE
            e_VP1, e_VP2, e_VP3, e_VP4 = lossNSpde(net, x_domain, y_domain, z_domain, t_domain)
            mse_NS = e_VP1 + e_VP2 + e_VP3 + e_VP4
            
            #Compute raw Loss (Used for our own reference)
            raw_loss = mse_IC + mse_BC + mse_NS  #+ mse_mass + mse_energy
            
            #Compute Weighted Loss (Used for iterative procedure)
            loss =   100*mse_BC + 100 * mse_IC + mse_NS #+ 1000*mse_phi #+ mse_mass + mse_energy
            '''
            print(net.parameters().is_leaf)

            ##############################################################################################
            #compute next step
            grad_pde_loss = torch.autograd.grad(mse_NS.sum(), param, create_graph=True, retain_graph=True)[0]
            grad_IC_loss = torch.autograd.grad(mse_IC.sum(), net.parameters(), create_graph=True, retain_graph=True)[0]
            grad_BC_loss = torch.autograd.grad(mse_BC.sum(), net.parameters(), create_graph=True, retain_graph=True)[0]
            # coeffiecient of BC => a, coeffiecient of IC => b
            a_next = (torch.max(torch.abs(grad_pde_loss))/(a*torch.max(torch.abs(grad_IC_loss)))).item() #10*
            b_next = (torch.max(torch.abs(grad_pde_loss))/(b*torch.max(torch.abs(grad_BC_loss)))).item() #10*
        
            # #update rates
            a = (1-lamba) * a + lamba * a_next
            b = (1-lamba) * b + lamba * b_next
            '''
            
            #step backward to compute gradients
            loss.backward()
            # Gradient Norm Clipping
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm = .1, error_if_nonfinite=False) #note max norm is more art than science
            
            #Make Iterative Step
            
            def closure():
                return loss
            
            net.optimizer.step(closure) #net.optimizer.step(closure)
            
            #Print and Record Raw Loss # "\n\tMass Loss: ", mse_mass.item(), "\tEnergy Loss: ", mse_energy.item()
            with torch.autograd.no_grad():
                if epoch%record_loss == 0:
                    epsilon = np.append(epsilon, raw_loss.cpu().detach().numpy())
                    #a_set = np.append(a_set, a.cpu().detach().numpy())
                    #b_set = np.append(b_set, b.cpu().detach().numpy())
                if epoch%print_loss == 0:
                    u_s,v_s,w_s,P_s = net(x_domain, y_domain, z_domain, t_domain)
                    u_s_val, v_s_val, w_s_val, P_s_val = net.u_eq(x_domain, y_domain, z_domain, t_domain), net.v_eq(x_domain, y_domain, z_domain, t_domain), net.w_eq(x_domain, y_domain, z_domain, t_domain), net.P_eq(x_domain, y_domain, z_domain, t_domain)
                    
                    #u_b,v_b,w_b,P_b = net(x_Bdry, y_Bdry, z_Bdry, t_Bdry)
                    #u_b_val, v_b_val, w_b_val, P_b_val = net.u_eq(x_Bdry, y_Bdry, z_Bdry, t_Bdry), net.v_eq(x_Bdry, y_Bdry, z_Bdry, t_Bdry), net.w_eq(x_Bdry, y_Bdry, z_Bdry, t_Bdry), net.P_eq(x_Bdry, y_Bdry, z_Bdry, t_Bdry)
                    
                    #u_i,v_i,w_i,P_i = net(x_IC, y_IC, z_IC, t_IC)
                    #u_i_val, v_i_val, w_i_val, P_i_val = net.u_eq(x_IC, y_IC, z_IC, t_IC), net.v_eq(x_IC, y_IC, z_IC, t_IC), net.w_eq(x_IC, y_IC, z_IC, t_IC), net.P_eq(x_IC, y_IC, z_IC, t_IC)
                    
                    rel_L2_u = 1/(Domain_collocation ) *(torch.sum(((u_s - u_s_val)**2/u_s_val**2)**.5))
                    rel_L2_v = 1/(Domain_collocation ) *(torch.sum(((v_s - v_s_val)**2/v_s_val**2)**.5))
                    rel_L2_w = 1/(Domain_collocation ) *(torch.sum(((w_s - w_s_val)**2/w_s_val**2)**.5))
                    rel_L2_P = 1/(Domain_collocation ) *(torch.sum(((P_s - P_s_val)**2/P_s_val**2)**.5))
                    
                    print("Iteration:", epoch, "\tTotal Loss:", loss.data)
                    print("u relative L2 errors: ", rel_L2_u.item(), "\tv relative L2 errors: ", rel_L2_v.item(),
                          "\tw relative L2 errors: ", rel_L2_w.item(), "\tP relative L2 errors: ", rel_L2_P.item(),
                        "\nIC Loss: ", mse_IC.item(), "\tDirichlet Bdry Loss: ", boundary_domain_loss.item(), "\tNS PDE Loss: ", mse_NS.item(),
                        "\ne_VP1 Loss: ", e_VP1.item(), "\t\te_VP2 Loss: ", e_VP2.item(), "\t\te_VP3 Loss: ", e_VP3.item(), "\t\te_VP4 Loss: ", e_VP4.item(), )
                    if mse_NS.cpu().detach().numpy() < min_mse_NS:
                        min_mse_NS = mse_NS.cpu().detach().numpy()
                        torch.save(net.state_dict(), f"ES_min_NSloss_lr{get_lr(net.optimizer)}_t{final_time}_{ctime}.pt")
                        print('  *Saved ; Early Stopping for the min NS PDE Loss\n')
                    if mse_IC.cpu().detach().numpy() < min_mse_IC:
                        min_mse_IC = mse_IC.cpu().detach().numpy()
                        torch.save(net.state_dict(), f"ES_min_mse_IC_lr{get_lr(net.optimizer)}_t{final_time}_{ctime}.pt")
                        print('  *Saved ; Early Stopping for the min IC Loss\n')
                    if loss.cpu().detach().numpy() < min_loss:
                        min_loss = loss.cpu().detach().numpy()
                        torch.save(net.state_dict(), f"ES_min_loss_lr{get_lr(net.optimizer)}_t{final_time}_{ctime}.pt")
                        print('  *Saved ; Early Stopping for the Minimal Total Loss\n')
                            
                        
        
        if final_time != time_slices[-1]:      
            torch.save(net.state_dict(), f"{ctime}NNlayers_lr{get_lr(net.optimizer)}_Bubble_ft_{final_time}.pt")
                
#create_network(True)
create_network(load=True, loadfile = "2_2_10hNNlayers_NSCH_0.pt")


# In[ ]:
# Out:
# Date of Today :  2  / 2
# Hour :  17
#
# Loading file was completed
#
# Training PDE
#
#
# Executing Pass 1
#
# Current Final Time: 1 Current Learning Rate:  0.001
# Iteration: 500 	Total Loss: tensor(0.0476)
# u relative L2 errors:  0.008960502222180367 	v relative L2 errors:  0.007272059563547373 	w relative L2 errors:  0.03587711229920387 	P relative L2 errors:  0.06032602861523628
# IC Loss:  8.455105125904083e-05 	Dirichlet Bdry Loss:  0.0002671129477676004 	NS PDE Loss:  0.012397976592183113
# e_VP1 Loss:  0.0033760257065296173 		e_VP2 Loss:  0.003925060387700796 		e_VP3 Loss:  0.004992086905986071 		e_VP4 Loss:  0.00010480358469067141
#   *Saved ; Early Stopping for the min NS PDE Loss
#
#   *Saved ; Early Stopping for the min IC Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 1000 	Total Loss: tensor(0.0470)
# u relative L2 errors:  0.00969809852540493 	v relative L2 errors:  0.007424218580126762 	w relative L2 errors:  0.058396466076374054 	P relative L2 errors:  0.06557997316122055
# IC Loss:  8.380055078305304e-05 	Dirichlet Bdry Loss:  0.00026708096265792847 	NS PDE Loss:  0.011925502680242062
# e_VP1 Loss:  0.0032588508911430836 		e_VP2 Loss:  0.003929886035621166 		e_VP3 Loss:  0.004637757316231728 		e_VP4 Loss:  9.900754957925528e-05
#   *Saved ; Early Stopping for the min NS PDE Loss
#
#   *Saved ; Early Stopping for the min IC Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 1500 	Total Loss: tensor(0.0473)
# u relative L2 errors:  0.008539141155779362 	v relative L2 errors:  0.2836861312389374 	w relative L2 errors:  0.06345269829034805 	P relative L2 errors:  0.07075542956590652
# IC Loss:  8.383468957617879e-05 	Dirichlet Bdry Loss:  0.00026126098237000406 	NS PDE Loss:  0.012759826146066189
# e_VP1 Loss:  0.0032733252737671137 		e_VP2 Loss:  0.004049703013151884 		e_VP3 Loss:  0.0053346650674939156 		e_VP4 Loss:  0.00010213214409304783
# Iteration: 2000 	Total Loss: tensor(0.0474)
# u relative L2 errors:  0.008970925584435463 	v relative L2 errors:  0.008466961793601513 	w relative L2 errors:  0.1508660912513733 	P relative L2 errors:  0.06495080888271332
# IC Loss:  8.255736611317843e-05 	Dirichlet Bdry Loss:  0.0002660225727595389 	NS PDE Loss:  0.012563436292111874
# e_VP1 Loss:  0.0031378157436847687 		e_VP2 Loss:  0.004984517116099596 		e_VP3 Loss:  0.004336261190474033 		e_VP4 Loss:  0.00010484272206667811
#   *Saved ; Early Stopping for the min IC Loss
#
# Iteration: 2500 	Total Loss: tensor(0.0471)
# u relative L2 errors:  0.009116405621170998 	v relative L2 errors:  0.009867418557405472 	w relative L2 errors:  0.2219637632369995 	P relative L2 errors:  0.06896718591451645
# IC Loss:  8.467560110148042e-05 	Dirichlet Bdry Loss:  0.00026976672234013677 	NS PDE Loss:  0.011637107469141483
# e_VP1 Loss:  0.003058707108721137 		e_VP2 Loss:  0.003910644445568323 		e_VP3 Loss:  0.00456555699929595 		e_VP4 Loss:  0.0001021987700369209
#   *Saved ; Early Stopping for the min NS PDE Loss
#
# Iteration: 3000 	Total Loss: tensor(0.0456)
# u relative L2 errors:  0.014166044071316719 	v relative L2 errors:  0.01379113458096981 	w relative L2 errors:  0.04377708584070206 	P relative L2 errors:  0.0669715404510498
# IC Loss:  7.92143982835114e-05 	Dirichlet Bdry Loss:  0.0002562989539001137 	NS PDE Loss:  0.012039963155984879
# e_VP1 Loss:  0.0034343055449426174 		e_VP2 Loss:  0.003993109334260225 		e_VP3 Loss:  0.004511758219450712 		e_VP4 Loss:  0.00010078951163450256
#   *Saved ; Early Stopping for the min IC Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 3500 	Total Loss: tensor(0.0480)
# u relative L2 errors:  0.010151476599276066 	v relative L2 errors:  0.010743662714958191 	w relative L2 errors:  0.05015895888209343 	P relative L2 errors:  0.061258409172296524
# IC Loss:  8.14833038020879e-05 	Dirichlet Bdry Loss:  0.00026268462534062564 	NS PDE Loss:  0.013600096106529236
# e_VP1 Loss:  0.003173127770423889 		e_VP2 Loss:  0.005022540222853422 		e_VP3 Loss:  0.0053008487448096275 		e_VP4 Loss:  0.0001035790191963315
# Iteration: 4000 	Total Loss: tensor(0.0474)
# u relative L2 errors:  0.02145012654364109 	v relative L2 errors:  0.01237061619758606 	w relative L2 errors:  0.04116063192486763 	P relative L2 errors:  0.06551355868577957
# IC Loss:  8.351852011401206e-05 	Dirichlet Bdry Loss:  0.000265881564700976 	NS PDE Loss:  0.012421690858900547
# e_VP1 Loss:  0.003303876146674156 		e_VP2 Loss:  0.004290576092898846 		e_VP3 Loss:  0.004724385682493448 		e_VP4 Loss:  0.00010285228199791163
# Iteration: 4500 	Total Loss: tensor(0.0467)
# u relative L2 errors:  0.010789441876113415 	v relative L2 errors:  0.008648655377328396 	w relative L2 errors:  0.057388171553611755 	P relative L2 errors:  0.06428069621324539
# IC Loss:  8.305440132971853e-05 	Dirichlet Bdry Loss:  0.00025900499895215034 	NS PDE Loss:  0.012465588748455048
# e_VP1 Loss:  0.003280217759311199 		e_VP2 Loss:  0.004311061464250088 		e_VP3 Loss:  0.004773092456161976 		e_VP4 Loss:  0.00010121733066625893
# Iteration: 5000 	Total Loss: tensor(0.0460)
# u relative L2 errors:  0.00970012228935957 	v relative L2 errors:  0.007088585291057825 	w relative L2 errors:  0.05548021197319031 	P relative L2 errors:  0.0743819996714592
# IC Loss:  8.180705481208861e-05 	Dirichlet Bdry Loss:  0.00026320602046325803 	NS PDE Loss:  0.011518839746713638
# e_VP1 Loss:  0.0033245745580643415 		e_VP2 Loss:  0.003674593288451433 		e_VP3 Loss:  0.004419049248099327 		e_VP4 Loss:  0.0001006231686915271
#   *Saved ; Early Stopping for the min NS PDE Loss
#
# Iteration: 5500 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.03422664850950241 	v relative L2 errors:  0.008248509839177132 	w relative L2 errors:  0.04430300369858742 	P relative L2 errors:  0.06982608139514923
# IC Loss:  8.148625056492165e-05 	Dirichlet Bdry Loss:  0.0002654939016792923 	NS PDE Loss:  0.011016855016350746
# e_VP1 Loss:  0.00284491921775043 		e_VP2 Loss:  0.0037080422043800354 		e_VP3 Loss:  0.0043609910644590855 		e_VP4 Loss:  0.00010290211503161117
#   *Saved ; Early Stopping for the min NS PDE Loss
#
# Iteration: 6000 	Total Loss: tensor(0.0466)
# u relative L2 errors:  0.013395735993981361 	v relative L2 errors:  0.007390424143522978 	w relative L2 errors:  0.07195768505334854 	P relative L2 errors:  0.06572410464286804
# IC Loss:  8.715532021597028e-05 	Dirichlet Bdry Loss:  0.00025963562075048685 	NS PDE Loss:  0.011965915560722351
# e_VP1 Loss:  0.0031058951281011105 		e_VP2 Loss:  0.004200235940515995 		e_VP3 Loss:  0.004557343665510416 		e_VP4 Loss:  0.00010244036820949987
# Iteration: 6500 	Total Loss: tensor(0.0460)
# u relative L2 errors:  0.02054658718407154 	v relative L2 errors:  0.006266818847507238 	w relative L2 errors:  0.06989285349845886 	P relative L2 errors:  0.0652192011475563
# IC Loss:  8.081833220785484e-05 	Dirichlet Bdry Loss:  0.0002616984711494297 	NS PDE Loss:  0.011715639382600784
# e_VP1 Loss:  0.0029016342014074326 		e_VP2 Loss:  0.004156405106186867 		e_VP3 Loss:  0.004555268678814173 		e_VP4 Loss:  0.00010233200737275183
# Iteration: 7000 	Total Loss: tensor(0.0472)
# u relative L2 errors:  0.015648119151592255 	v relative L2 errors:  0.006173424422740936 	w relative L2 errors:  0.04539521783590317 	P relative L2 errors:  0.059563010931015015
# IC Loss:  8.463873382424936e-05 	Dirichlet Bdry Loss:  0.0002632427494972944 	NS PDE Loss:  0.012420176528394222
# e_VP1 Loss:  0.003225954482331872 		e_VP2 Loss:  0.0043779839761555195 		e_VP3 Loss:  0.004712325055152178 		e_VP4 Loss:  0.00010391244722995907
# Iteration: 7500 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.009890910238027573 	v relative L2 errors:  0.025860518217086792 	w relative L2 errors:  0.03855680301785469 	P relative L2 errors:  0.06843561679124832
# IC Loss:  8.093517681118101e-05 	Dirichlet Bdry Loss:  0.0002604220062494278 	NS PDE Loss:  0.011524712666869164
# e_VP1 Loss:  0.0030792977195233107 		e_VP2 Loss:  0.003757830010727048 		e_VP3 Loss:  0.004585160408169031 		e_VP4 Loss:  0.00010242452844977379
# Iteration: 8000 	Total Loss: tensor(0.0471)
# u relative L2 errors:  0.009054658003151417 	v relative L2 errors:  0.006863795220851898 	w relative L2 errors:  0.041267503052949905 	P relative L2 errors:  0.06411772966384888
# IC Loss:  8.674513082951307e-05 	Dirichlet Bdry Loss:  0.00026230092043988407 	NS PDE Loss:  0.01221800222992897
# e_VP1 Loss:  0.003119752276688814 		e_VP2 Loss:  0.0043282718397676945 		e_VP3 Loss:  0.004668169654905796 		e_VP4 Loss:  0.00010180847311858088
# Iteration: 8500 	Total Loss: tensor(0.0467)
# u relative L2 errors:  0.01154988631606102 	v relative L2 errors:  0.008750737644731998 	w relative L2 errors:  0.4962761700153351 	P relative L2 errors:  0.06194509193301201
# IC Loss:  8.132580842357129e-05 	Dirichlet Bdry Loss:  0.0002641025639604777 	NS PDE Loss:  0.01214803010225296
# e_VP1 Loss:  0.0032082379329949617 		e_VP2 Loss:  0.004120074678212404 		e_VP3 Loss:  0.0047136819921433926 		e_VP4 Loss:  0.0001060349604813382
# Iteration: 9000 	Total Loss: tensor(0.0506)
# u relative L2 errors:  0.012892480008304119 	v relative L2 errors:  0.012624622322618961 	w relative L2 errors:  0.04970555007457733 	P relative L2 errors:  0.06459947675466537
# IC Loss:  8.134359086398035e-05 	Dirichlet Bdry Loss:  0.0002642761683091521 	NS PDE Loss:  0.015989812090992928
# e_VP1 Loss:  0.00368150370195508 		e_VP2 Loss:  0.004818294662982225 		e_VP3 Loss:  0.0073898667469620705 		e_VP4 Loss:  0.00010014655708801001
# Iteration: 9500 	Total Loss: tensor(0.0471)
# u relative L2 errors:  0.009285499341785908 	v relative L2 errors:  0.014259597286581993 	w relative L2 errors:  0.03696113079786301 	P relative L2 errors:  0.06289351731538773
# IC Loss:  8.567670010961592e-05 	Dirichlet Bdry Loss:  0.00025944531080313027 	NS PDE Loss:  0.012603885494172573
# e_VP1 Loss:  0.003233744064345956 		e_VP2 Loss:  0.004392886999994516 		e_VP3 Loss:  0.00487544434145093 		e_VP4 Loss:  0.00010180945537285879
# Iteration: 10000 	Total Loss: tensor(0.0469)
# u relative L2 errors:  0.010421532206237316 	v relative L2 errors:  0.009527651593089104 	w relative L2 errors:  0.04539819806814194 	P relative L2 errors:  0.06898089498281479
# IC Loss:  8.519527909811586e-05 	Dirichlet Bdry Loss:  0.00026952862390317023 	NS PDE Loss:  0.011416907422244549
# e_VP1 Loss:  0.0032403133809566498 		e_VP2 Loss:  0.003843583632260561 		e_VP3 Loss:  0.004234842024743557 		e_VP4 Loss:  9.816821693675593e-05
# Iteration: 10500 	Total Loss: tensor(0.0467)
# u relative L2 errors:  0.011416684836149216 	v relative L2 errors:  0.007091304752975702 	w relative L2 errors:  0.049907900393009186 	P relative L2 errors:  0.08589554578065872
# IC Loss:  8.009061275515705e-05 	Dirichlet Bdry Loss:  0.0002661713515408337 	NS PDE Loss:  0.012099876999855042
# e_VP1 Loss:  0.003243220504373312 		e_VP2 Loss:  0.004268390126526356 		e_VP3 Loss:  0.0044865733943879604 		e_VP4 Loss:  0.00010169269808102399
# Iteration: 11000 	Total Loss: tensor(0.0470)
# u relative L2 errors:  0.010349645279347897 	v relative L2 errors:  0.012164374813437462 	w relative L2 errors:  0.034932952374219894 	P relative L2 errors:  0.06659499555826187
# IC Loss:  8.345430251210928e-05 	Dirichlet Bdry Loss:  0.0002618231519591063 	NS PDE Loss:  0.01251259632408619
# e_VP1 Loss:  0.0032753844279795885 		e_VP2 Loss:  0.004323040600866079 		e_VP3 Loss:  0.004810572136193514 		e_VP4 Loss:  0.00010359839507145807
# Iteration: 11500 	Total Loss: tensor(0.0472)
# u relative L2 errors:  0.011144471354782581 	v relative L2 errors:  0.006663316860795021 	w relative L2 errors:  0.4791903793811798 	P relative L2 errors:  0.07186191529035568
# IC Loss:  8.125849126372486e-05 	Dirichlet Bdry Loss:  0.0002681317273527384 	NS PDE Loss:  0.012226786464452744
# e_VP1 Loss:  0.0031549271661788225 		e_VP2 Loss:  0.0040067704394459724 		e_VP3 Loss:  0.004962952341884375 		e_VP4 Loss:  0.0001021365897031501
# Iteration: 12000 	Total Loss: tensor(0.0465)
# u relative L2 errors:  0.008563418872654438 	v relative L2 errors:  0.012061704881489277 	w relative L2 errors:  0.05894369259476662 	P relative L2 errors:  0.07168342918157578
# IC Loss:  8.0156656622421e-05 	Dirichlet Bdry Loss:  0.00027037825202569366 	NS PDE Loss:  0.011445742100477219
# e_VP1 Loss:  0.0031236151698976755 		e_VP2 Loss:  0.0038833413273096085 		e_VP3 Loss:  0.004335345234721899 		e_VP4 Loss:  0.00010344055044697598
# Iteration: 12500 	Total Loss: tensor(0.0456)
# u relative L2 errors:  0.01131945475935936 	v relative L2 errors:  0.008736575953662395 	w relative L2 errors:  0.03799843415617943 	P relative L2 errors:  0.06700862944126129
# IC Loss:  8.052028715610504e-05 	Dirichlet Bdry Loss:  0.00026076071662828326 	NS PDE Loss:  0.011517574079334736
# e_VP1 Loss:  0.0028698635287582874 		e_VP2 Loss:  0.004024687688797712 		e_VP3 Loss:  0.004521068185567856 		e_VP4 Loss:  0.00010195456707151607
# Iteration: 13000 	Total Loss: tensor(0.0471)
# u relative L2 errors:  0.009093263186514378 	v relative L2 errors:  0.013847697526216507 	w relative L2 errors:  0.03347178176045418 	P relative L2 errors:  0.07044592499732971
# IC Loss:  8.256926957983524e-05 	Dirichlet Bdry Loss:  0.00026115140644833446 	NS PDE Loss:  0.012744791805744171
# e_VP1 Loss:  0.0032779877074062824 		e_VP2 Loss:  0.004496026784181595 		e_VP3 Loss:  0.004864446818828583 		e_VP4 Loss:  0.00010633072815835476
# Iteration: 13500 	Total Loss: tensor(0.0469)
# u relative L2 errors:  0.00878142099827528 	v relative L2 errors:  0.006973141338676214 	w relative L2 errors:  0.047355689108371735 	P relative L2 errors:  0.0685969740152359
# IC Loss:  8.007533324416727e-05 	Dirichlet Bdry Loss:  0.00026691617676988244 	NS PDE Loss:  0.012223138473927975
# e_VP1 Loss:  0.003283278550952673 		e_VP2 Loss:  0.00416669063270092 		e_VP3 Loss:  0.004669258836656809 		e_VP4 Loss:  0.00010391039540991187
# Iteration: 14000 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.009994512423872948 	v relative L2 errors:  0.014255008660256863 	w relative L2 errors:  0.055504441261291504 	P relative L2 errors:  0.06747515499591827
# IC Loss:  8.322405483340845e-05 	Dirichlet Bdry Loss:  0.00026026577688753605 	NS PDE Loss:  0.012063601985573769
# e_VP1 Loss:  0.0035285435151308775 		e_VP2 Loss:  0.003981258254498243 		e_VP3 Loss:  0.004454900976270437 		e_VP4 Loss:  9.889863576972857e-05
# Iteration: 14500 	Total Loss: tensor(0.0459)
# u relative L2 errors:  0.014280114322900772 	v relative L2 errors:  0.009882677346467972 	w relative L2 errors:  0.037613946944475174 	P relative L2 errors:  0.06689104437828064
# IC Loss:  8.184630132745951e-05 	Dirichlet Bdry Loss:  0.00025700428523123264 	NS PDE Loss:  0.01199673768132925
# e_VP1 Loss:  0.003049602499231696 		e_VP2 Loss:  0.004208759870380163 		e_VP3 Loss:  0.004637330304831266 		e_VP4 Loss:  0.00010104559623869136
# Iteration: 15000 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.01018619630485773 	v relative L2 errors:  0.006843624636530876 	w relative L2 errors:  0.04593469575047493 	P relative L2 errors:  0.05960187688469887
# IC Loss:  8.106977475108579e-05 	Dirichlet Bdry Loss:  0.00026368655380792916 	NS PDE Loss:  0.011675641871988773
# e_VP1 Loss:  0.003127538599073887 		e_VP2 Loss:  0.003904003417119384 		e_VP3 Loss:  0.004544827155768871 		e_VP4 Loss:  9.927273640641943e-05
# Iteration: 15500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.009161172434687614 	v relative L2 errors:  0.009554170072078705 	w relative L2 errors:  0.0481998473405838 	P relative L2 errors:  0.059724267572164536
# IC Loss:  8.028355659916997e-05 	Dirichlet Bdry Loss:  0.0002635206619743258 	NS PDE Loss:  0.011393035762012005
# e_VP1 Loss:  0.00325406389310956 		e_VP2 Loss:  0.0037181961815804243 		e_VP3 Loss:  0.004319807980209589 		e_VP4 Loss:  0.00010096750338561833
# Iteration: 16000 	Total Loss: tensor(0.0461)
# u relative L2 errors:  0.008703114464879036 	v relative L2 errors:  0.010994063690304756 	w relative L2 errors:  0.0375596359372139 	P relative L2 errors:  0.07131551206111908
# IC Loss:  8.134933887049556e-05 	Dirichlet Bdry Loss:  0.0002524969168007374 	NS PDE Loss:  0.012715687043964863
# e_VP1 Loss:  0.003451073542237282 		e_VP2 Loss:  0.004405861720442772 		e_VP3 Loss:  0.004753716755658388 		e_VP4 Loss:  0.00010503579687792808
# Iteration: 16500 	Total Loss: tensor(0.0455)
# u relative L2 errors:  0.008319574408233166 	v relative L2 errors:  0.007838060148060322 	w relative L2 errors:  0.08212685585021973 	P relative L2 errors:  0.06503817439079285
# IC Loss:  8.118100231513381e-05 	Dirichlet Bdry Loss:  0.000252727884799242 	NS PDE Loss:  0.012122762389481068
# e_VP1 Loss:  0.0032050777226686478 		e_VP2 Loss:  0.0040391478687524796 		e_VP3 Loss:  0.004777155350893736 		e_VP4 Loss:  0.00010138109064428136
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 17000 	Total Loss: tensor(0.0465)
# u relative L2 errors:  0.010036212392151356 	v relative L2 errors:  0.006895462516695261 	w relative L2 errors:  0.03485763445496559 	P relative L2 errors:  0.08925424516201019
# IC Loss:  8.256628643721342e-05 	Dirichlet Bdry Loss:  0.0002640640886966139 	NS PDE Loss:  0.011822307482361794
# e_VP1 Loss:  0.0032463152892887592 		e_VP2 Loss:  0.003958791494369507 		e_VP3 Loss:  0.004515877924859524 		e_VP4 Loss:  0.00010132200986845419
# Iteration: 17500 	Total Loss: tensor(0.0473)
# u relative L2 errors:  0.00980240199714899 	v relative L2 errors:  0.011115098372101784 	w relative L2 errors:  0.03828653320670128 	P relative L2 errors:  0.06756541877985
# IC Loss:  8.314118895214051e-05 	Dirichlet Bdry Loss:  0.0002660934696905315 	NS PDE Loss:  0.012422128580510616
# e_VP1 Loss:  0.003301414428278804 		e_VP2 Loss:  0.004427075386047363 		e_VP3 Loss:  0.004590785130858421 		e_VP4 Loss:  0.00010285352618666366
# Iteration: 18000 	Total Loss: tensor(0.0472)
# u relative L2 errors:  0.012975585646927357 	v relative L2 errors:  0.01311266329139471 	w relative L2 errors:  0.08372163772583008 	P relative L2 errors:  0.06456191837787628
# IC Loss:  8.801881631370634e-05 	Dirichlet Bdry Loss:  0.0002630878589116037 	NS PDE Loss:  0.012066861614584923
# e_VP1 Loss:  0.0032220627181231976 		e_VP2 Loss:  0.0042389859445393085 		e_VP3 Loss:  0.0045053171925246716 		e_VP4 Loss:  0.00010049516276922077
# Iteration: 18500 	Total Loss: tensor(0.0459)
# u relative L2 errors:  0.011451813392341137 	v relative L2 errors:  0.11829393357038498 	w relative L2 errors:  0.11066097021102905 	P relative L2 errors:  0.0667380541563034
# IC Loss:  8.158486161846668e-05 	Dirichlet Bdry Loss:  0.000261058536125347 	NS PDE Loss:  0.01161468867212534
# e_VP1 Loss:  0.0033676945604383945 		e_VP2 Loss:  0.0037397549021989107 		e_VP3 Loss:  0.0044050561264157295 		e_VP4 Loss:  0.00010218265379080549
# Iteration: 19000 	Total Loss: tensor(0.0476)
# u relative L2 errors:  0.009349432773888111 	v relative L2 errors:  0.008893287740647793 	w relative L2 errors:  0.03622233122587204 	P relative L2 errors:  0.06876930594444275
# IC Loss:  8.529333717888221e-05 	Dirichlet Bdry Loss:  0.00026977056404575706 	NS PDE Loss:  0.012051642872393131
# e_VP1 Loss:  0.00319475750438869 		e_VP2 Loss:  0.004072483628988266 		e_VP3 Loss:  0.004681372083723545 		e_VP4 Loss:  0.00010302985901944339
# Iteration: 19500 	Total Loss: tensor(0.0467)
# u relative L2 errors:  0.01253201998770237 	v relative L2 errors:  0.011791985481977463 	w relative L2 errors:  0.09794075787067413 	P relative L2 errors:  0.06598936766386032
# IC Loss:  8.317033643834293e-05 	Dirichlet Bdry Loss:  0.0002627615467645228 	NS PDE Loss:  0.0121158417314291
# e_VP1 Loss:  0.003099958412349224 		e_VP2 Loss:  0.0042177955619990826 		e_VP3 Loss:  0.004696456715464592 		e_VP4 Loss:  0.00010163155820919201
# Iteration: 20000 	Total Loss: tensor(0.0460)
# u relative L2 errors:  0.020365498960018158 	v relative L2 errors:  0.054550107568502426 	w relative L2 errors:  0.048050299286842346 	P relative L2 errors:  0.05924096703529358
# IC Loss:  8.441567479167134e-05 	Dirichlet Bdry Loss:  0.0002593469398561865 	NS PDE Loss:  0.01163530070334673
# e_VP1 Loss:  0.0030927155166864395 		e_VP2 Loss:  0.003795858472585678 		e_VP3 Loss:  0.0046410528011620045 		e_VP4 Loss:  0.000105674633232411
# Iteration: 20500 	Total Loss: tensor(0.0467)
# u relative L2 errors:  0.015108400024473667 	v relative L2 errors:  0.007782374508678913 	w relative L2 errors:  0.03840223699808121 	P relative L2 errors:  0.06793468445539474
# IC Loss:  8.275343861896545e-05 	Dirichlet Bdry Loss:  0.00026017881464213133 	NS PDE Loss:  0.012388053350150585
# e_VP1 Loss:  0.0030193047132343054 		e_VP2 Loss:  0.00480851111933589 		e_VP3 Loss:  0.004453573375940323 		e_VP4 Loss:  0.00010666417801985517
# Iteration: 21000 	Total Loss: tensor(0.0460)
# u relative L2 errors:  0.007952536456286907 	v relative L2 errors:  0.008228672668337822 	w relative L2 errors:  0.03813168779015541 	P relative L2 errors:  0.06388933956623077
# IC Loss:  8.37802654132247e-05 	Dirichlet Bdry Loss:  0.000257966632489115 	NS PDE Loss:  0.011839224025607109
# e_VP1 Loss:  0.0031577625777572393 		e_VP2 Loss:  0.003932155203074217 		e_VP3 Loss:  0.004644431173801422 		e_VP4 Loss:  0.00010487569670658559
# Iteration: 21500 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.012133300304412842 	v relative L2 errors:  0.014141690917313099 	w relative L2 errors:  0.040555715560913086 	P relative L2 errors:  0.06330087780952454
# IC Loss:  8.182373130694032e-05 	Dirichlet Bdry Loss:  0.00025705411098897457 	NS PDE Loss:  0.012273264117538929
# e_VP1 Loss:  0.0030743866227567196 		e_VP2 Loss:  0.004277655854821205 		e_VP3 Loss:  0.004819228779524565 		e_VP4 Loss:  0.00010199289681622759
# Iteration: 22000 	Total Loss: tensor(0.0461)
# u relative L2 errors:  0.012543207965791225 	v relative L2 errors:  0.010859823785722256 	w relative L2 errors:  0.036182671785354614 	P relative L2 errors:  0.07108156383037567
# IC Loss:  8.611394150648266e-05 	Dirichlet Bdry Loss:  0.0002619450388010591 	NS PDE Loss:  0.011290499940514565
# e_VP1 Loss:  0.002900347812101245 		e_VP2 Loss:  0.0037072093691676855 		e_VP3 Loss:  0.004582760389894247 		e_VP4 Loss:  0.00010018263856181875
# Iteration: 22500 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.011236319318413734 	v relative L2 errors:  0.011739346198737621 	w relative L2 errors:  0.0332908071577549 	P relative L2 errors:  0.07134697586297989
# IC Loss:  8.317957690451294e-05 	Dirichlet Bdry Loss:  0.0002602929889690131 	NS PDE Loss:  0.011829460971057415
# e_VP1 Loss:  0.0031149766873568296 		e_VP2 Loss:  0.0039667366072535515 		e_VP3 Loss:  0.004643520340323448 		e_VP4 Loss:  0.00010422697232570499
# Iteration: 23000 	Total Loss: tensor(0.0480)
# u relative L2 errors:  0.018156103789806366 	v relative L2 errors:  0.009550762362778187 	w relative L2 errors:  0.05080324411392212 	P relative L2 errors:  0.06396839767694473
# IC Loss:  8.41039145598188e-05 	Dirichlet Bdry Loss:  0.00026593965594656765 	NS PDE Loss:  0.013005881570279598
# e_VP1 Loss:  0.0030779025983065367 		e_VP2 Loss:  0.00391112407669425 		e_VP3 Loss:  0.005917704198509455 		e_VP4 Loss:  9.915132250171155e-05
# Iteration: 23500 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.008212854154407978 	v relative L2 errors:  0.006602362729609013 	w relative L2 errors:  0.06747117638587952 	P relative L2 errors:  0.06095891073346138
# IC Loss:  8.268853707704693e-05 	Dirichlet Bdry Loss:  0.0002621299645397812 	NS PDE Loss:  0.011241651140153408
# e_VP1 Loss:  0.002971133915707469 		e_VP2 Loss:  0.0037879960145801306 		e_VP3 Loss:  0.0043801176361739635 		e_VP4 Loss:  0.0001024033990688622
# Iteration: 24000 	Total Loss: tensor(0.0477)
# u relative L2 errors:  0.008974943310022354 	v relative L2 errors:  0.015987304970622063 	w relative L2 errors:  0.041683245450258255 	P relative L2 errors:  0.06778087466955185
# IC Loss:  8.281382906716317e-05 	Dirichlet Bdry Loss:  0.00026644571335054934 	NS PDE Loss:  0.012774776667356491
# e_VP1 Loss:  0.003166043199598789 		e_VP2 Loss:  0.003840791992843151 		e_VP3 Loss:  0.005661773029714823 		e_VP4 Loss:  0.00010616909275995567
# Iteration: 24500 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.0082338135689497 	v relative L2 errors:  0.006976354867219925 	w relative L2 errors:  0.03174765408039093 	P relative L2 errors:  0.0625363290309906
# IC Loss:  8.297667955048382e-05 	Dirichlet Bdry Loss:  0.0002617972204461694 	NS PDE Loss:  0.01193477213382721
# e_VP1 Loss:  0.003128238720819354 		e_VP2 Loss:  0.00394145492464304 		e_VP3 Loss:  0.004760370124131441 		e_VP4 Loss:  0.00010470832785358652
# Iteration: 25000 	Total Loss: tensor(0.0470)
# u relative L2 errors:  0.010587676428258419 	v relative L2 errors:  0.01027530524879694 	w relative L2 errors:  0.037890512496232986 	P relative L2 errors:  0.06541544944047928
# IC Loss:  8.137628901749849e-05 	Dirichlet Bdry Loss:  0.0002656061842571944 	NS PDE Loss:  0.012341164983808994
# e_VP1 Loss:  0.0031784093007445335 		e_VP2 Loss:  0.004432547837495804 		e_VP3 Loss:  0.00462720450013876 		e_VP4 Loss:  0.00010300295252818614
# Iteration: 25500 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.012038150802254677 	v relative L2 errors:  0.0075281341560184956 	w relative L2 errors:  0.09120060503482819 	P relative L2 errors:  0.06638774275779724
# IC Loss:  8.308480028063059e-05 	Dirichlet Bdry Loss:  0.00026454366161487997 	NS PDE Loss:  0.01141340471804142
# e_VP1 Loss:  0.0030914044473320246 		e_VP2 Loss:  0.003936070948839188 		e_VP3 Loss:  0.004287939518690109 		e_VP4 Loss:  9.798993414733559e-05
# Iteration: 26000 	Total Loss: tensor(0.0455)
# u relative L2 errors:  0.008621100336313248 	v relative L2 errors:  0.00844630692154169 	w relative L2 errors:  0.044049181044101715 	P relative L2 errors:  0.06339011341333389
# IC Loss:  8.559446723666042e-05 	Dirichlet Bdry Loss:  0.0002497848472557962 	NS PDE Loss:  0.01193656213581562
# e_VP1 Loss:  0.003013111185282469 		e_VP2 Loss:  0.004037173930555582 		e_VP3 Loss:  0.004785721190273762 		e_VP4 Loss:  0.00010055559687316418
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 26500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.011992552317678928 	v relative L2 errors:  0.008552268147468567 	w relative L2 errors:  0.03588693588972092 	P relative L2 errors:  0.06862794607877731
# IC Loss:  8.384729881072417e-05 	Dirichlet Bdry Loss:  0.00025591254234313965 	NS PDE Loss:  0.011785285547375679
# e_VP1 Loss:  0.003082048846408725 		e_VP2 Loss:  0.003927537240087986 		e_VP3 Loss:  0.004672100301831961 		e_VP4 Loss:  0.00010359873704146594
# Iteration: 27000 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.010982726700603962 	v relative L2 errors:  0.02341173030436039 	w relative L2 errors:  0.03253711014986038 	P relative L2 errors:  0.0641317069530487
# IC Loss:  8.303052163682878e-05 	Dirichlet Bdry Loss:  0.00025462746270932257 	NS PDE Loss:  0.012015517801046371
# e_VP1 Loss:  0.003276055445894599 		e_VP2 Loss:  0.004099676385521889 		e_VP3 Loss:  0.004538047127425671 		e_VP4 Loss:  0.00010173836926696822
# Iteration: 27500 	Total Loss: tensor(0.0467)
# u relative L2 errors:  0.008311576209962368 	v relative L2 errors:  0.009939215146005154 	w relative L2 errors:  0.05609714239835739 	P relative L2 errors:  0.06786628812551498
# IC Loss:  7.979170186445117e-05 	Dirichlet Bdry Loss:  0.0002695046423468739 	NS PDE Loss:  0.011740176938474178
# e_VP1 Loss:  0.003253262024372816 		e_VP2 Loss:  0.003948170691728592 		e_VP3 Loss:  0.00443967105820775 		e_VP4 Loss:  9.90728585748002e-05
# Iteration: 28000 	Total Loss: tensor(0.0453)
# u relative L2 errors:  0.008159410208463669 	v relative L2 errors:  0.007905211299657822 	w relative L2 errors:  0.042633093893527985 	P relative L2 errors:  0.07141508907079697
# IC Loss:  8.032184996409342e-05 	Dirichlet Bdry Loss:  0.0002551493525970727 	NS PDE Loss:  0.01179046742618084
# e_VP1 Loss:  0.003164065768942237 		e_VP2 Loss:  0.0038711861707270145 		e_VP3 Loss:  0.004653377458453178 		e_VP4 Loss:  0.00010183870472246781
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 28500 	Total Loss: tensor(0.0472)
# u relative L2 errors:  0.010693318210542202 	v relative L2 errors:  0.008298229426145554 	w relative L2 errors:  0.04941640794277191 	P relative L2 errors:  0.06276930123567581
# IC Loss:  8.520481060259044e-05 	Dirichlet Bdry Loss:  0.00025980922509916127 	NS PDE Loss:  0.01266834419220686
# e_VP1 Loss:  0.003121074056252837 		e_VP2 Loss:  0.004408644512295723 		e_VP3 Loss:  0.005034852772951126 		e_VP4 Loss:  0.00010377260332461447
# Iteration: 29000 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.00767107680439949 	v relative L2 errors:  0.01211442332714796 	w relative L2 errors:  0.04072495177388191 	P relative L2 errors:  0.06737849116325378
# IC Loss:  8.008233271539211e-05 	Dirichlet Bdry Loss:  0.00025665550492703915 	NS PDE Loss:  0.012014687992632389
# e_VP1 Loss:  0.0032030376605689526 		e_VP2 Loss:  0.003965346608310938 		e_VP3 Loss:  0.004746092017740011 		e_VP4 Loss:  0.00010021132038673386
# Iteration: 29500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.00802103616297245 	v relative L2 errors:  0.008288108743727207 	w relative L2 errors:  0.03948459401726723 	P relative L2 errors:  0.06553366780281067
# IC Loss:  8.103129948722199e-05 	Dirichlet Bdry Loss:  0.0002566716866567731 	NS PDE Loss:  0.0120486905798316
# e_VP1 Loss:  0.0033010742627084255 		e_VP2 Loss:  0.004040434490889311 		e_VP3 Loss:  0.004605716560035944 		e_VP4 Loss:  0.00010146491695195436
# Iteration: 30000 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.03023351915180683 	v relative L2 errors:  0.017159275710582733 	w relative L2 errors:  0.04107922688126564 	P relative L2 errors:  0.2364369034767151
# IC Loss:  8.03515431471169e-05 	Dirichlet Bdry Loss:  0.0002669529931154102 	NS PDE Loss:  0.011442834511399269
# e_VP1 Loss:  0.0029917238280177116 		e_VP2 Loss:  0.0038513222243636847 		e_VP3 Loss:  0.004500042647123337 		e_VP4 Loss:  9.974583372240886e-05
#
#
# Executing Pass 2
#
# Current Final Time: 1 Current Learning Rate:  0.001
# Iteration: 500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.011214631609618664 	v relative L2 errors:  0.010267623700201511 	w relative L2 errors:  0.043311551213264465 	P relative L2 errors:  0.06599131226539612
# IC Loss:  8.185715705621988e-05 	Dirichlet Bdry Loss:  0.0002547084877733141 	NS PDE Loss:  0.012188059277832508
# e_VP1 Loss:  0.003273153677582741 		e_VP2 Loss:  0.004174252972006798 		e_VP3 Loss:  0.00463705463334918 		e_VP4 Loss:  0.0001035970781231299
#   *Saved ; Early Stopping for the min NS PDE Loss
#
#   *Saved ; Early Stopping for the min IC Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 1000 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.08560091257095337 	v relative L2 errors:  0.01075729075819254 	w relative L2 errors:  0.028661681339144707 	P relative L2 errors:  0.0682259052991867
# IC Loss:  8.260620234068483e-05 	Dirichlet Bdry Loss:  0.00025706057203933597 	NS PDE Loss:  0.01168875116854906
# e_VP1 Loss:  0.0029886544216424227 		e_VP2 Loss:  0.003944202326238155 		e_VP3 Loss:  0.004653749521821737 		e_VP4 Loss:  0.00010214458598056808
#   *Saved ; Early Stopping for the min NS PDE Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 1500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.007685468997806311 	v relative L2 errors:  0.008431977592408657 	w relative L2 errors:  0.03267529606819153 	P relative L2 errors:  0.1298866719007492
# IC Loss:  8.311803685501218e-05 	Dirichlet Bdry Loss:  0.00025457306765019894 	NS PDE Loss:  0.012075637467205524
# e_VP1 Loss:  0.0032607249449938536 		e_VP2 Loss:  0.004051122814416885 		e_VP3 Loss:  0.004661399871110916 		e_VP4 Loss:  0.00010238969116471708
# Iteration: 2000 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.00989887397736311 	v relative L2 errors:  0.008014333434402943 	w relative L2 errors:  0.0362410694360733 	P relative L2 errors:  0.07633451372385025
# IC Loss:  8.412738679908216e-05 	Dirichlet Bdry Loss:  0.0002585589827504009 	NS PDE Loss:  0.011912737041711807
# e_VP1 Loss:  0.003140967572107911 		e_VP2 Loss:  0.0039580282755196095 		e_VP3 Loss:  0.004709796980023384 		e_VP4 Loss:  0.00010394371929578483
# Iteration: 2500 	Total Loss: tensor(0.0468)
# u relative L2 errors:  0.01058561448007822 	v relative L2 errors:  0.02063177339732647 	w relative L2 errors:  0.03919333964586258 	P relative L2 errors:  0.06355024129152298
# IC Loss:  8.058699313551188e-05 	Dirichlet Bdry Loss:  0.00026806266396306455 	NS PDE Loss:  0.011962229385972023
# e_VP1 Loss:  0.0034800132270902395 		e_VP2 Loss:  0.0039071980863809586 		e_VP3 Loss:  0.004472999833524227 		e_VP4 Loss:  0.00010201805707765743
#   *Saved ; Early Stopping for the min IC Loss
#
# Iteration: 3000 	Total Loss: tensor(0.0461)
# u relative L2 errors:  0.008785939775407314 	v relative L2 errors:  0.008888723328709602 	w relative L2 errors:  0.03290252014994621 	P relative L2 errors:  0.06877075880765915
# IC Loss:  8.4511331806425e-05 	Dirichlet Bdry Loss:  0.00025700454716570675 	NS PDE Loss:  0.01191327627748251
# e_VP1 Loss:  0.0031189362052828074 		e_VP2 Loss:  0.004113242495805025 		e_VP3 Loss:  0.004581272602081299 		e_VP4 Loss:  9.982513438444585e-05
# Iteration: 3500 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.010927850380539894 	v relative L2 errors:  0.00936784315854311 	w relative L2 errors:  0.0352262407541275 	P relative L2 errors:  0.059927165508270264
# IC Loss:  8.306773088406771e-05 	Dirichlet Bdry Loss:  0.00025899516185745597 	NS PDE Loss:  0.012216870673000813
# e_VP1 Loss:  0.003256868338212371 		e_VP2 Loss:  0.0040590944699943066 		e_VP3 Loss:  0.004798697307705879 		e_VP4 Loss:  0.00010221047705272213
# Iteration: 4000 	Total Loss: tensor(0.0461)
# u relative L2 errors:  0.01442977599799633 	v relative L2 errors:  0.007545728236436844 	w relative L2 errors:  0.06067708134651184 	P relative L2 errors:  0.07227588444948196
# IC Loss:  8.115178206935525e-05 	Dirichlet Bdry Loss:  0.0002592726086732 	NS PDE Loss:  0.012106901034712791
# e_VP1 Loss:  0.0031513867434114218 		e_VP2 Loss:  0.003934370819479227 		e_VP3 Loss:  0.004916165489703417 		e_VP4 Loss:  0.00010497828770894557
# Iteration: 4500 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.010015654377639294 	v relative L2 errors:  0.009863115847110748 	w relative L2 errors:  0.03347567096352577 	P relative L2 errors:  0.06434258073568344
# IC Loss:  8.523660653736442e-05 	Dirichlet Bdry Loss:  0.00025724852457642555 	NS PDE Loss:  0.011992762796580791
# e_VP1 Loss:  0.003073805710300803 		e_VP2 Loss:  0.0040697394870221615 		e_VP3 Loss:  0.004745678976178169 		e_VP4 Loss:  0.00010353868128731847
# Iteration: 5000 	Total Loss: tensor(0.0478)
# u relative L2 errors:  0.009855235926806927 	v relative L2 errors:  0.0064451019279658794 	w relative L2 errors:  0.03803667053580284 	P relative L2 errors:  0.07529238611459732
# IC Loss:  8.508621249347925e-05 	Dirichlet Bdry Loss:  0.0002603466564323753 	NS PDE Loss:  0.013211434707045555
# e_VP1 Loss:  0.003390505677089095 		e_VP2 Loss:  0.004122969228774309 		e_VP3 Loss:  0.005595644470304251 		e_VP4 Loss:  0.00010231518535874784
# Iteration: 5500 	Total Loss: tensor(0.0454)
# u relative L2 errors:  0.1055205687880516 	v relative L2 errors:  0.011326845735311508 	w relative L2 errors:  0.05834677070379257 	P relative L2 errors:  0.06025181710720062
# IC Loss:  7.961905066622421e-05 	Dirichlet Bdry Loss:  0.0002562809968367219 	NS PDE Loss:  0.011761248111724854
# e_VP1 Loss:  0.00334743270650506 		e_VP2 Loss:  0.003751026466488838 		e_VP3 Loss:  0.004561292938888073 		e_VP4 Loss:  0.00010149543231818825
#   *Saved ; Early Stopping for the min IC Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 6000 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.010844952426850796 	v relative L2 errors:  0.008482255041599274 	w relative L2 errors:  0.04691382497549057 	P relative L2 errors:  0.0705600306391716
# IC Loss:  8.231514220824465e-05 	Dirichlet Bdry Loss:  0.00025770696811378 	NS PDE Loss:  0.012412327341735363
# e_VP1 Loss:  0.00334749068133533 		e_VP2 Loss:  0.004377494566142559 		e_VP3 Loss:  0.004586387425661087 		e_VP4 Loss:  0.00010095416655531153
# Iteration: 6500 	Total Loss: tensor(0.0456)
# u relative L2 errors:  0.0199863500893116 	v relative L2 errors:  0.010177330113947392 	w relative L2 errors:  0.05229850858449936 	P relative L2 errors:  0.06023433804512024
# IC Loss:  8.179594442481175e-05 	Dirichlet Bdry Loss:  0.0002566146431490779 	NS PDE Loss:  0.011744051240384579
# e_VP1 Loss:  0.0033361290115863085 		e_VP2 Loss:  0.003888677107170224 		e_VP3 Loss:  0.004417790099978447 		e_VP4 Loss:  0.00010145526175620034
# Iteration: 7000 	Total Loss: tensor(0.0466)
# u relative L2 errors:  0.010605229996144772 	v relative L2 errors:  0.013884810730814934 	w relative L2 errors:  0.04343106225132942 	P relative L2 errors:  0.06211128830909729
# IC Loss:  8.473564230371267e-05 	Dirichlet Bdry Loss:  0.00025685428408905864 	NS PDE Loss:  0.012436563149094582
# e_VP1 Loss:  0.003293281188234687 		e_VP2 Loss:  0.004370932932943106 		e_VP3 Loss:  0.00467115780338645 		e_VP4 Loss:  0.00010119178477907553
# Iteration: 7500 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.011901658028364182 	v relative L2 errors:  0.04414718970656395 	w relative L2 errors:  0.03391813486814499 	P relative L2 errors:  0.06781996786594391
# IC Loss:  8.293781866086647e-05 	Dirichlet Bdry Loss:  0.00025774940149858594 	NS PDE Loss:  0.012361300177872181
# e_VP1 Loss:  0.0033992333337664604 		e_VP2 Loss:  0.004210981540381908 		e_VP3 Loss:  0.004652407020330429 		e_VP4 Loss:  9.867860353551805e-05
# Iteration: 8000 	Total Loss: tensor(0.0456)
# u relative L2 errors:  0.02414616011083126 	v relative L2 errors:  0.007773036602884531 	w relative L2 errors:  0.044772423803806305 	P relative L2 errors:  0.06718361377716064
# IC Loss:  8.055169018916786e-05 	Dirichlet Bdry Loss:  0.0002577679406385869 	NS PDE Loss:  0.011760003864765167
# e_VP1 Loss:  0.0030883385334163904 		e_VP2 Loss:  0.003838364500552416 		e_VP3 Loss:  0.0047299908474087715 		e_VP4 Loss:  0.00010330937948310748
# Iteration: 8500 	Total Loss: tensor(0.0465)
# u relative L2 errors:  0.014629049226641655 	v relative L2 errors:  0.00950431264936924 	w relative L2 errors:  0.04462152719497681 	P relative L2 errors:  0.06373271346092224
# IC Loss:  8.346210233867168e-05 	Dirichlet Bdry Loss:  0.0002556374529376626 	NS PDE Loss:  0.012619860470294952
# e_VP1 Loss:  0.003291660686954856 		e_VP2 Loss:  0.004531333688646555 		e_VP3 Loss:  0.004692487884312868 		e_VP4 Loss:  0.00010437849414302036
# Iteration: 9000 	Total Loss: tensor(0.0456)
# u relative L2 errors:  0.016928091645240784 	v relative L2 errors:  0.007391134276986122 	w relative L2 errors:  0.05675873905420303 	P relative L2 errors:  0.08464301377534866
# IC Loss:  8.214967238018289e-05 	Dirichlet Bdry Loss:  0.0002566968905739486 	NS PDE Loss:  0.011757791973650455
# e_VP1 Loss:  0.0031667135190218687 		e_VP2 Loss:  0.003782521467655897 		e_VP3 Loss:  0.004710298962891102 		e_VP4 Loss:  9.825820598052815e-05
# Iteration: 9500 	Total Loss: tensor(0.0455)
# u relative L2 errors:  0.009225837886333466 	v relative L2 errors:  0.008178281597793102 	w relative L2 errors:  0.03195568174123764 	P relative L2 errors:  0.07461301982402802
# IC Loss:  7.767420902382582e-05 	Dirichlet Bdry Loss:  0.0002461057738400996 	NS PDE Loss:  0.013150880113244057
# e_VP1 Loss:  0.0032369133550673723 		e_VP2 Loss:  0.004542963579297066 		e_VP3 Loss:  0.005268898326903582 		e_VP4 Loss:  0.00010210498294327408
#   *Saved ; Early Stopping for the min IC Loss
#
# Iteration: 10000 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.009005710482597351 	v relative L2 errors:  0.008003029972314835 	w relative L2 errors:  0.035839423537254333 	P relative L2 errors:  0.07936222851276398
# IC Loss:  8.329050615429878e-05 	Dirichlet Bdry Loss:  0.0002599281433504075 	NS PDE Loss:  0.011828267946839333
# e_VP1 Loss:  0.0032214645761996508 		e_VP2 Loss:  0.004189111292362213 		e_VP3 Loss:  0.00431792950257659 		e_VP4 Loss:  9.976347064366564e-05
# Iteration: 10500 	Total Loss: tensor(0.0444)
# u relative L2 errors:  0.043351657688617706 	v relative L2 errors:  0.007219318766146898 	w relative L2 errors:  0.06271982192993164 	P relative L2 errors:  0.060542501509189606
# IC Loss:  7.90776321082376e-05 	Dirichlet Bdry Loss:  0.0002497700334060937 	NS PDE Loss:  0.011544613167643547
# e_VP1 Loss:  0.003022061428055167 		e_VP2 Loss:  0.0038848258554935455 		e_VP3 Loss:  0.004535864572972059 		e_VP4 Loss:  0.0001018607581499964
#   *Saved ; Early Stopping for the min NS PDE Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 11000 	Total Loss: tensor(0.0452)
# u relative L2 errors:  0.01039046235382557 	v relative L2 errors:  0.007430074270814657 	w relative L2 errors:  0.08735016733407974 	P relative L2 errors:  0.06464815884828568
# IC Loss:  7.798189471941441e-05 	Dirichlet Bdry Loss:  0.00025624921545386314 	NS PDE Loss:  0.011804921552538872
# e_VP1 Loss:  0.0033555878326296806 		e_VP2 Loss:  0.003983772825449705 		e_VP3 Loss:  0.004365212749689817 		e_VP4 Loss:  0.00010034775914391503
# Iteration: 11500 	Total Loss: tensor(0.0459)
# u relative L2 errors:  0.011413519270718098 	v relative L2 errors:  0.008880767971277237 	w relative L2 errors:  0.04054194688796997 	P relative L2 errors:  0.0604996457695961
# IC Loss:  8.259523747256026e-05 	Dirichlet Bdry Loss:  0.000254155311267823 	NS PDE Loss:  0.01225803978741169
# e_VP1 Loss:  0.0031992492731660604 		e_VP2 Loss:  0.00439158920198679 		e_VP3 Loss:  0.0045677549205720425 		e_VP4 Loss:  9.944627527147532e-05
# Iteration: 12000 	Total Loss: tensor(0.0465)
# u relative L2 errors:  0.024098599329590797 	v relative L2 errors:  0.007281847298145294 	w relative L2 errors:  0.03100735694169998 	P relative L2 errors:  0.05925465002655983
# IC Loss:  8.394769974984229e-05 	Dirichlet Bdry Loss:  0.00025590750738047063 	NS PDE Loss:  0.01254902221262455
# e_VP1 Loss:  0.0031229297164827585 		e_VP2 Loss:  0.004357864148914814 		e_VP3 Loss:  0.004962801467627287 		e_VP4 Loss:  0.00010542777454247698
# Iteration: 12500 	Total Loss: tensor(0.0462)
# u relative L2 errors:  0.013563393615186214 	v relative L2 errors:  0.00888260081410408 	w relative L2 errors:  0.036099597811698914 	P relative L2 errors:  0.07175517082214355
# IC Loss:  8.822738891467452e-05 	Dirichlet Bdry Loss:  0.0002540373243391514 	NS PDE Loss:  0.01196406688541174
# e_VP1 Loss:  0.00330986175686121 		e_VP2 Loss:  0.00402074446901679 		e_VP3 Loss:  0.004533003084361553 		e_VP4 Loss:  0.00010045681119663641
# Iteration: 13000 	Total Loss: tensor(0.0452)
# u relative L2 errors:  0.009629575535655022 	v relative L2 errors:  0.007691537961363792 	w relative L2 errors:  0.03335362300276756 	P relative L2 errors:  0.06757274270057678
# IC Loss:  8.644861372886226e-05 	Dirichlet Bdry Loss:  0.0002511246129870415 	NS PDE Loss:  0.011456295847892761
# e_VP1 Loss:  0.003152173012495041 		e_VP2 Loss:  0.0038026946131139994 		e_VP3 Loss:  0.004401548765599728 		e_VP4 Loss:  9.987999510485679e-05
#   *Saved ; Early Stopping for the min NS PDE Loss
#
# Iteration: 13500 	Total Loss: tensor(0.0459)
# u relative L2 errors:  0.011501355096697807 	v relative L2 errors:  0.0681580975651741 	w relative L2 errors:  0.04935072362422943 	P relative L2 errors:  0.07364331930875778
# IC Loss:  8.60743093653582e-05 	Dirichlet Bdry Loss:  0.0002566868788562715 	NS PDE Loss:  0.011628971435129642
# e_VP1 Loss:  0.0030108990613371134 		e_VP2 Loss:  0.00403115339577198 		e_VP3 Loss:  0.004484437871724367 		e_VP4 Loss:  0.00010248139733448625
# Iteration: 14000 	Total Loss: tensor(0.0450)
# u relative L2 errors:  0.017892973497509956 	v relative L2 errors:  0.008306034840643406 	w relative L2 errors:  0.0678999200463295 	P relative L2 errors:  0.07406431436538696
# IC Loss:  8.18876433186233e-05 	Dirichlet Bdry Loss:  0.0002492686326149851 	NS PDE Loss:  0.01188619714230299
# e_VP1 Loss:  0.003144449321553111 		e_VP2 Loss:  0.0036947086919099092 		e_VP3 Loss:  0.004947768524289131 		e_VP4 Loss:  9.927099745254964e-05
# Iteration: 14500 	Total Loss: tensor(0.0455)
# u relative L2 errors:  0.00893467292189598 	v relative L2 errors:  0.00792759656906128 	w relative L2 errors:  0.045310135930776596 	P relative L2 errors:  0.06828431040048599
# IC Loss:  8.498351962771267e-05 	Dirichlet Bdry Loss:  0.00024876376846805215 	NS PDE Loss:  0.01214862335473299
# e_VP1 Loss:  0.003110698889940977 		e_VP2 Loss:  0.003936587367206812 		e_VP3 Loss:  0.004998695570975542 		e_VP4 Loss:  0.00010264210868626833
# Iteration: 15000 	Total Loss: tensor(0.0454)
# u relative L2 errors:  0.07082364708185196 	v relative L2 errors:  0.03053979016840458 	w relative L2 errors:  0.25141963362693787 	P relative L2 errors:  0.06593480706214905
# IC Loss:  7.91227794252336e-05 	Dirichlet Bdry Loss:  0.0002492208732292056 	NS PDE Loss:  0.012592252343893051
# e_VP1 Loss:  0.0030914796516299248 		e_VP2 Loss:  0.004780988674610853 		e_VP3 Loss:  0.00461542746052146 		e_VP4 Loss:  0.00010435636067995802
# Iteration: 15500 	Total Loss: tensor(0.0453)
# u relative L2 errors:  0.030461782589554787 	v relative L2 errors:  0.009398248046636581 	w relative L2 errors:  0.043975699692964554 	P relative L2 errors:  0.06677412241697311
# IC Loss:  8.374876051675528e-05 	Dirichlet Bdry Loss:  0.0002518285473342985 	NS PDE Loss:  0.011777297593653202
# e_VP1 Loss:  0.003179089166224003 		e_VP2 Loss:  0.003945040516555309 		e_VP3 Loss:  0.00455143628641963 		e_VP4 Loss:  0.00010173146438319236
# Iteration: 16000 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.01449219323694706 	v relative L2 errors:  0.012772186659276485 	w relative L2 errors:  0.06223456189036369 	P relative L2 errors:  0.06772104650735855
# IC Loss:  7.989283767528832e-05 	Dirichlet Bdry Loss:  0.00025857845321297646 	NS PDE Loss:  0.012531065382063389
# e_VP1 Loss:  0.003443976631388068 		e_VP2 Loss:  0.004413418006151915 		e_VP3 Loss:  0.004570300225168467 		e_VP4 Loss:  0.00010336993000237271
# Iteration: 16500 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.00961372535675764 	v relative L2 errors:  0.0069380225613713264 	w relative L2 errors:  0.06303296238183975 	P relative L2 errors:  0.06805042922496796
# IC Loss:  7.87331591709517e-05 	Dirichlet Bdry Loss:  0.0002639048034325242 	NS PDE Loss:  0.012138353660702705
# e_VP1 Loss:  0.0032308497466146946 		e_VP2 Loss:  0.003998898901045322 		e_VP3 Loss:  0.004805540665984154 		e_VP4 Loss:  0.0001030642306432128
# Iteration: 17000 	Total Loss: tensor(0.0465)
# u relative L2 errors:  0.011827684938907623 	v relative L2 errors:  0.011392640881240368 	w relative L2 errors:  0.04003947600722313 	P relative L2 errors:  0.06256739050149918
# IC Loss:  8.029775199247524e-05 	Dirichlet Bdry Loss:  0.00024901825236156583 	NS PDE Loss:  0.013574674725532532
# e_VP1 Loss:  0.003340017981827259 		e_VP2 Loss:  0.004923216532915831 		e_VP3 Loss:  0.005204190965741873 		e_VP4 Loss:  0.00010724907770054415
# Iteration: 17500 	Total Loss: tensor(0.0456)
# u relative L2 errors:  0.007947181351482868 	v relative L2 errors:  0.008725385181605816 	w relative L2 errors:  0.031028399243950844 	P relative L2 errors:  0.07246921211481094
# IC Loss:  8.555237582186237e-05 	Dirichlet Bdry Loss:  0.0002490065526217222 	NS PDE Loss:  0.012176593765616417
# e_VP1 Loss:  0.0032625519670546055 		e_VP2 Loss:  0.004182165488600731 		e_VP3 Loss:  0.004629184026271105 		e_VP4 Loss:  0.0001026926256599836
# Iteration: 18000 	Total Loss: tensor(0.0449)
# u relative L2 errors:  0.014181176200509071 	v relative L2 errors:  0.007402035873383284 	w relative L2 errors:  0.04335850849747658 	P relative L2 errors:  0.06296924501657486
# IC Loss:  7.836869190214202e-05 	Dirichlet Bdry Loss:  0.0002492329222150147 	NS PDE Loss:  0.01210436038672924
# e_VP1 Loss:  0.0030851580668240786 		e_VP2 Loss:  0.00386135745793581 		e_VP3 Loss:  0.0050526829436421394 		e_VP4 Loss:  0.00010516173642827198
# Iteration: 18500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.016485091298818588 	v relative L2 errors:  0.0062674893997609615 	w relative L2 errors:  0.05079197511076927 	P relative L2 errors:  0.067612424492836
# ...
# Iteration: 4000 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.019836079329252243 	v relative L2 errors:  0.01221036072820425 	w relative L2 errors:  0.037865523248910904 	P relative L2 errors:  0.062002550810575485
# IC Loss:  7.87818426033482e-05 	Dirichlet Bdry Loss:  0.00025759515119716525 	NS PDE Loss:  0.012111364863812923
# e_VP1 Loss:  0.0032641009893268347 		e_VP2 Loss:  0.003935107961297035 		e_VP3 Loss:  0.004810843151062727 		e_VP4 Loss:  0.00010131250746781006
#   *Saved ; Early Stopping for the min IC Loss
#
# Iteration: 4500 	Total Loss: tensor(0.0452)
# u relative L2 errors:  0.009791480377316475 	v relative L2 errors:  0.05717068910598755 	w relative L2 errors:  0.16715052723884583 	P relative L2 errors:  0.08486323803663254
# IC Loss:  8.314108708873391e-05 	Dirichlet Bdry Loss:  0.00025313644437119365 	NS PDE Loss:  0.011554040014743805
# e_VP1 Loss:  0.0031753741204738617 		e_VP2 Loss:  0.003770657815039158 		e_VP3 Loss:  0.004505522083491087 		e_VP4 Loss:  0.00010248667967971414
#   *Saved ; Early Stopping for the min NS PDE Loss
#
# Iteration: 5000 	Total Loss: tensor(0.0442)
# u relative L2 errors:  0.0078081367537379265 	v relative L2 errors:  0.03537735715508461 	w relative L2 errors:  0.03521529957652092 	P relative L2 errors:  0.06657827645540237
# IC Loss:  7.975008338689804e-05 	Dirichlet Bdry Loss:  0.0002478266542311758 	NS PDE Loss:  0.011488230898976326
# e_VP1 Loss:  0.0030957956332713366 		e_VP2 Loss:  0.004040658473968506 		e_VP3 Loss:  0.004251705016940832 		e_VP4 Loss:  0.00010007282253354788
#   *Saved ; Early Stopping for the min NS PDE Loss
#
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 5500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.010149825364351273 	v relative L2 errors:  0.007217107806354761 	w relative L2 errors:  0.03548341989517212 	P relative L2 errors:  0.0698452889919281
# IC Loss:  8.161153527908027e-05 	Dirichlet Bdry Loss:  0.00025245369761250913 	NS PDE Loss:  0.012403279542922974
# e_VP1 Loss:  0.0036866215523332357 		e_VP2 Loss:  0.004165246617048979 		e_VP3 Loss:  0.004452694207429886 		e_VP4 Loss:  9.871735528577119e-05
# Iteration: 6000 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.012034712359309196 	v relative L2 errors:  0.012891651131212711 	w relative L2 errors:  0.030382392928004265 	P relative L2 errors:  0.06404227018356323
# IC Loss:  8.087947207968682e-05 	Dirichlet Bdry Loss:  0.00025221146643161774 	NS PDE Loss:  0.012435701675713062
# e_VP1 Loss:  0.0036585484631359577 		e_VP2 Loss:  0.004057761747390032 		e_VP3 Loss:  0.004618178587406874 		e_VP4 Loss:  0.0001012134162010625
# Iteration: 6500 	Total Loss: tensor(0.0457)
# u relative L2 errors:  0.009189623408019543 	v relative L2 errors:  0.012865519151091576 	w relative L2 errors:  0.0362432561814785 	P relative L2 errors:  0.06454354524612427
# IC Loss:  8.395369513891637e-05 	Dirichlet Bdry Loss:  0.00025477338931523263 	NS PDE Loss:  0.011785635724663734
# e_VP1 Loss:  0.0032443192321807146 		e_VP2 Loss:  0.004169062711298466 		e_VP3 Loss:  0.004269111435860395 		e_VP4 Loss:  0.00010314197425032035
# Iteration: 7000 	Total Loss: tensor(0.0454)
# u relative L2 errors:  0.009904242120683193 	v relative L2 errors:  0.008445467799901962 	w relative L2 errors:  0.028501486405730247 	P relative L2 errors:  0.0661356970667839
# IC Loss:  8.210803207475692e-05 	Dirichlet Bdry Loss:  0.00025607921998016536 	NS PDE Loss:  0.0115968594327569
# e_VP1 Loss:  0.003095146967098117 		e_VP2 Loss:  0.004123484715819359 		e_VP3 Loss:  0.004276200197637081 		e_VP4 Loss:  0.0001020270210574381
# Iteration: 7500 	Total Loss: tensor(0.0465)
# u relative L2 errors:  0.009822026826441288 	v relative L2 errors:  0.013129559345543385 	w relative L2 errors:  0.034024789929389954 	P relative L2 errors:  0.06469372659921646
# IC Loss:  8.183282625395805e-05 	Dirichlet Bdry Loss:  0.0002577748673502356 	NS PDE Loss:  0.012489506974816322
# e_VP1 Loss:  0.0031586503610014915 		e_VP2 Loss:  0.004273248370736837 		e_VP3 Loss:  0.004952939227223396 		e_VP4 Loss:  0.00010466945241205394
# Iteration: 8000 	Total Loss: tensor(0.0456)
# u relative L2 errors:  0.015227697789669037 	v relative L2 errors:  0.011758582666516304 	w relative L2 errors:  0.03964700177311897 	P relative L2 errors:  0.0655217170715332
# IC Loss:  8.332782454090193e-05 	Dirichlet Bdry Loss:  0.00024699236382730305 	NS PDE Loss:  0.012569964863359928
# e_VP1 Loss:  0.003373783780261874 		e_VP2 Loss:  0.00424044206738472 		e_VP3 Loss:  0.004854382481426001 		e_VP4 Loss:  0.00010135697084479034
# Iteration: 8500 	Total Loss: tensor(0.0453)
# u relative L2 errors:  0.010297855362296104 	v relative L2 errors:  0.008993216790258884 	w relative L2 errors:  0.04158290475606918 	P relative L2 errors:  0.06765884906053543
# IC Loss:  7.9366858699359e-05 	Dirichlet Bdry Loss:  0.00025669659953564405 	NS PDE Loss:  0.011686253361403942
# e_VP1 Loss:  0.0032188056502491236 		e_VP2 Loss:  0.00401070574298501 		e_VP3 Loss:  0.0043549020774662495 		e_VP4 Loss:  0.00010183938866248354
# Iteration: 9000 	Total Loss: tensor(0.0451)
# u relative L2 errors:  0.010746880434453487 	v relative L2 errors:  0.006757861003279686 	w relative L2 errors:  0.0553695484995842 	P relative L2 errors:  0.09573063254356384
# IC Loss:  8.119062840705737e-05 	Dirichlet Bdry Loss:  0.0002510345366317779 	NS PDE Loss:  0.011900722049176693
# e_VP1 Loss:  0.00311802770011127 		e_VP2 Loss:  0.003978291526436806 		e_VP3 Loss:  0.004701986908912659 		e_VP4 Loss:  0.00010241584823234007
# Iteration: 9500 	Total Loss: tensor(0.0442)
# u relative L2 errors:  0.013446538709104061 	v relative L2 errors:  0.010631365701556206 	w relative L2 errors:  0.037948738783597946 	P relative L2 errors:  0.06230209767818451
# IC Loss:  7.909414853202179e-05 	Dirichlet Bdry Loss:  0.0002469622704666108 	NS PDE Loss:  0.01161886565387249
# e_VP1 Loss:  0.003257687436416745 		e_VP2 Loss:  0.0038675693795084953 		e_VP3 Loss:  0.004392196424305439 		e_VP4 Loss:  0.00010141270468011498
#   *Saved ; Early Stopping for the Minimal Total Loss
#
# Iteration: 10000 	Total Loss: tensor(0.0454)
# u relative L2 errors:  0.013228294439613819 	v relative L2 errors:  0.011451547034084797 	w relative L2 errors:  0.030475860461592674 	P relative L2 errors:  0.05970950052142143
# IC Loss:  8.151165093295276e-05 	Dirichlet Bdry Loss:  0.00024889575433917344 	NS PDE Loss:  0.01239695493131876
# e_VP1 Loss:  0.003203226951882243 		e_VP2 Loss:  0.004285047296434641 		e_VP3 Loss:  0.004802447743713856 		e_VP4 Loss:  0.0001062335868482478
# Iteration: 10500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.009870640002191067 	v relative L2 errors:  0.006758337374776602 	w relative L2 errors:  0.03426516801118851 	P relative L2 errors:  0.06417503207921982
# IC Loss:  8.313989383168519e-05 	Dirichlet Bdry Loss:  0.0002586182381492108 	NS PDE Loss:  0.01163466926664114
# e_VP1 Loss:  0.0030688252300024033 		e_VP2 Loss:  0.00401843897998333 		e_VP3 Loss:  0.004443982150405645 		e_VP4 Loss:  0.00010342285531805828
# Iteration: 11000 	Total Loss: tensor(0.0453)
# u relative L2 errors:  0.27292558550834656 	v relative L2 errors:  0.017816148698329926 	w relative L2 errors:  0.04312118887901306 	P relative L2 errors:  0.08214303851127625
# IC Loss:  8.088298636721447e-05 	Dirichlet Bdry Loss:  0.00025376552366651595 	NS PDE Loss:  0.011786587536334991
# e_VP1 Loss:  0.00302464934065938 		e_VP2 Loss:  0.003995066974312067 		e_VP3 Loss:  0.004663784056901932 		e_VP4 Loss:  0.00010308717173757032
# Iteration: 11500 	Total Loss: tensor(0.0464)
# u relative L2 errors:  0.011568745598196983 	v relative L2 errors:  0.02065250091254711 	w relative L2 errors:  0.09908492118120193 	P relative L2 errors:  0.06521384418010712
# IC Loss:  8.171459194272757e-05 	Dirichlet Bdry Loss:  0.00025797050329856575 	NS PDE Loss:  0.01243177056312561
# e_VP1 Loss:  0.003413041355088353 		e_VP2 Loss:  0.00418624933809042 		e_VP3 Loss:  0.004729586187750101 		e_VP4 Loss:  0.00010289468627888709
# Iteration: 12000 	Total Loss: tensor(0.0445)
# u relative L2 errors:  0.008508872240781784 	v relative L2 errors:  0.007021582685410976 	w relative L2 errors:  0.036550287157297134 	P relative L2 errors:  0.06794610619544983
# IC Loss:  8.705892105353996e-05 	Dirichlet Bdry Loss:  0.00024441396817564964 	NS PDE Loss:  0.011329099535942078
# e_VP1 Loss:  0.003114706836640835 		e_VP2 Loss:  0.0038997605443000793 		e_VP3 Loss:  0.0042158737778663635 		e_VP4 Loss:  9.875848627416417e-05
#   *Saved ; Early Stopping for the min NS PDE Loss
#
# Iteration: 12500 	Total Loss: tensor(0.0459)
# u relative L2 errors:  0.011461378075182438 	v relative L2 errors:  0.012323789298534393 	w relative L2 errors:  0.05432433262467384 	P relative L2 errors:  0.07884129136800766
# IC Loss:  8.306709059979767e-05 	Dirichlet Bdry Loss:  0.0002525497111491859 	NS PDE Loss:  0.01235886663198471
# e_VP1 Loss:  0.003198868129402399 		e_VP2 Loss:  0.004539045039564371 		e_VP3 Loss:  0.00451958691701293 		e_VP4 Loss:  0.0001013674700516276
# Iteration: 13000 	Total Loss: tensor(0.0468)
# u relative L2 errors:  0.008369218558073044 	v relative L2 errors:  0.006445263512432575 	w relative L2 errors:  0.034379150718450546 	P relative L2 errors:  0.08004643023014069
# IC Loss:  8.179077121894807e-05 	Dirichlet Bdry Loss:  0.0002621572057250887 	NS PDE Loss:  0.01242445781826973
# e_VP1 Loss:  0.0032701001036912203 		e_VP2 Loss:  0.003950269427150488 		e_VP3 Loss:  0.005102985538542271 		e_VP4 Loss:  0.00010110294533660635
# Iteration: 13500 	Total Loss: tensor(0.0449)
# u relative L2 errors:  0.011030121706426144 	v relative L2 errors:  0.008730082772672176 	w relative L2 errors:  0.06872393935918808 	P relative L2 errors:  0.08113635331392288
# IC Loss:  8.292771235574037e-05 	Dirichlet Bdry Loss:  0.0002522518625482917 	NS PDE Loss:  0.011426333338022232
# e_VP1 Loss:  0.003135053440928459 		e_VP2 Loss:  0.003963983152061701 		e_VP3 Loss:  0.0042246985249221325 		e_VP4 Loss:  0.00010259866394335404
# Iteration: 14000 	Total Loss: tensor(0.0446)
# u relative L2 errors:  0.011639891192317009 	v relative L2 errors:  0.017458777874708176 	w relative L2 errors:  0.0345754399895668 	P relative L2 errors:  0.06638116389513016
# IC Loss:  8.294587314594537e-05 	Dirichlet Bdry Loss:  0.000248149735853076 	NS PDE Loss:  0.011461476795375347
# e_VP1 Loss:  0.0030319008510559797 		e_VP2 Loss:  0.003945351578295231 		e_VP3 Loss:  0.004383330699056387 		e_VP4 Loss:  0.00010089307033922523
# Iteration: 14500 	Total Loss: tensor(0.0458)
# u relative L2 errors:  0.02445937693119049 	v relative L2 errors:  0.011723886243999004 	w relative L2 errors:  0.029289433732628822 	P relative L2 errors:  0.06692638993263245
# IC Loss:  8.053561032284051e-05 	Dirichlet Bdry Loss:  0.0002485073637217283 	NS PDE Loss:  0.012855873443186283
# e_VP1 Loss:  0.0036655806470662355 		e_VP2 Loss:  0.004412074573338032 		e_VP3 Loss:  0.004674192517995834 		e_VP4 Loss:  0.00010402579209767282
# Iteration: 15000 	Total Loss: tensor(0.0447)
# u relative L2 errors:  0.01401671301573515 	v relative L2 errors:  0.008716478943824768 	w relative L2 errors:  0.030030205845832825 	P relative L2 errors:  0.06007976457476616
# IC Loss:  8.11103091109544e-05 	Dirichlet Bdry Loss:  0.0002477119560353458 	NS PDE Loss:  0.011784978210926056
# e_VP1 Loss:  0.003077893750742078 		e_VP2 Loss:  0.00402312446385622 		e_VP3 Loss:  0.004582902416586876 		e_VP4 Loss:  0.00010105751425726339
# Iteration: 15500 	Total Loss: tensor(0.0460)
# u relative L2 errors:  0.008785918354988098 	v relative L2 errors:  0.009163503535091877 	w relative L2 errors:  0.027853557839989662 	P relative L2 errors:  0.07156187295913696
# IC Loss:  8.449066081084311e-05 	Dirichlet Bdry Loss:  0.00025296956300735474 	NS PDE Loss:  0.012296411208808422
# e_VP1 Loss:  0.0032291938550770283 		e_VP2 Loss:  0.004541752859950066 		e_VP3 Loss:  0.004424054641276598 		e_VP4 Loss:  0.00010140996892005205
# Iteration: 16000 	Total Loss: tensor(0.0454)
# u relative L2 errors:  0.007751920726150274 	v relative L2 errors:  0.006697644479572773 	w relative L2 errors:  0.04955202341079712 	P relative L2 errors:  0.05895661562681198
# IC Loss:  8.31370271043852e-05 	Dirichlet Bdry Loss:  0.0002504198928363621 	NS PDE Loss:  0.01203586533665657
# e_VP1 Loss:  0.003198783379048109 		e_VP2 Loss:  0.004303104244172573 		e_VP3 Loss:  0.004433145746588707 		e_VP4 Loss:  0.00010083230881718919
# Iteration: 16500 	Total Loss: tensor(0.0450)
# u relative L2 errors:  0.00983333308249712 	v relative L2 errors:  0.008201321586966515 	w relative L2 errors:  0.14201559126377106 	P relative L2 errors:  0.07258620113134384
# IC Loss:  8.326503302669153e-05 	Dirichlet Bdry Loss:  0.00024325374397449195 	NS PDE Loss:  0.01233302429318428
# e_VP1 Loss:  0.0032339454628527164 		e_VP2 Loss:  0.0042677223682403564 		e_VP3 Loss:  0.004728158935904503 		e_VP4 Loss:  0.000103197613498196
# Iteration: 17000 	Total Loss: tensor(0.0459)
# u relative L2 errors:  0.029519448056817055 	v relative L2 errors:  0.011699562892317772 	w relative L2 errors:  0.4438278079032898 	P relative L2 errors:  0.0727817490696907
# IC Loss:  8.453960617771372e-05 	Dirichlet Bdry Loss:  0.0002522930153645575 	NS PDE Loss:  0.012187604792416096
# e_VP1 Loss:  0.0033920512069016695 		e_VP2 Loss:  0.004236032720655203 		e_VP3 Loss:  0.004455749876797199 		e_VP4 Loss:  0.00010377058788435534
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 441
#     438             torch.save(net.state_dict(), f"{ctime}NNlayers_lr{get_lr(net.optimizer)}_Bubble_ft_{final_time}.pt")
#     440 #create_network(True)
# --> 441 create_network(load=True, loadfile = "2_2_10hNNlayers_NSCH_0.pt")
#     444 # In[ ]:
#
# Cell In[1], line 87, in create_network(load, loadfile)
#      84     iterations = 30000
#      85     learning_rate = 10**-4
# ---> 87 training_loop(net, time_slices, iterations, learning_rate, IC_coefficient = 1, record_loss = 100, print_loss = 500, a = a, b = b)
#      90 torch.save(net.state_dict(), f"{ctime}NNlayers_NSCH_{i}.pt")
#      91 np.savetxt('epsilon.txt', epsilon)
#
# Cell In[1], line 359, in training_loop(net, time_slices, iterations, learning_rate, IC_coefficient, record_loss, print_loss, a, b)
#     356 mse_BC = boundary_domain_loss
#     358 #Loss based on PDE
# --> 359 e_VP1, e_VP2, e_VP3, e_VP4 = lossNSpde(net, x_domain, y_domain, z_domain, t_domain)
#     360 mse_NS = e_VP1 + e_VP2 + e_VP3 + e_VP4
#     362 #Compute raw Loss (Used for our own reference)
#
# File ~/Desktop/1_15_NSFnets/NSpde_loss.py:45, in lossNSpde(net, x, y, z, t)
#      42 u_t = torch.autograd.grad(u.sum(), t,create_graph=True)[0]
#      44 v_x = torch.autograd.grad(v.sum(), x,create_graph=True)[0]
# ---> 45 v_xx = torch.autograd.grad(v_x.sum(), x,create_graph=True)[0]
#      46 v_y = torch.autograd.grad(v.sum(), y,create_graph=True)[0]
#      47 v_yy = torch.autograd.grad(v_y.sum(), y,create_graph=True)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/autograd/__init__.py:411, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     407     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     408         grad_outputs_
#     409     )
#     410 else:
# --> 411     result = Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     412         t_outputs,
#     413         grad_outputs_,
#     414         retain_graph,
#     415         create_graph,
#     416         inputs,
#     417         allow_unused,
#     418         accumulate_grad=False,
#     419     )  # Calls into the C++ engine to run the backward pass
#     420 if materialize_grads:
#     421     if any(
#     422         result[i] is None and not is_tensor_like(inputs[i])
#     423         for i in range(len(inputs))
#     424     ):
#
# KeyboardInterrupt:
