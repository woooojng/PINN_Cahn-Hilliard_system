# %%
import torch
import numpy as np
from torch.autograd import Variable
from scipy.stats import qmc
import time
import shutil
import os

from datetime import datetime

from Building_Net import Net
from Conditions import lossIC, lossBdry,lossNSpde, lossNSpde_rank

currentDateTime = datetime.now()
print("Date of Today : ", currentDateTime.month, " /", currentDateTime.day, "\nHour : ", currentDateTime.hour) 
ctime = f"{currentDateTime.month}_{currentDateTime.day}_{currentDateTime.hour}h"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")




def create_network(load, loadfile):
    
    net = Net()
    net = net.to(device)
    epsilon = []
    #Attempt to load the saved pt. file
    if load == True:
        try:
            net.load_state_dict(torch.load(loadfile, map_location=torch.device(device)))
        except:
            print("\nLoading file was failed\n")
        else:
            print("\nLoading file was completed\n")
    
    print('Training PDE')
    start = time.time() #initialize tracking computational time
    
    partial_time_set = [0, 0, 0] #initialize time recording list with number of learnning rates on whole domain training
    
    for i in range(len(partial_time_set)):
        if i == 0:
            #First loop uses progressively increasing time intervals
            print(f'\n\nTraining Pass {i+1}')
            time_slices = np.array([ .3, .4, .5, .6, .7, .8, .9, 1]) #.1, .2,
            iterations = 100 #iterations for each learning rate
            learning_rate = 10**-3
        elif i == 1:
            print(f'\n\nTraining Pass {i+1}')
            #time_slices = [time_slices[-1]]
            time_slices = [time_slices[-1]]
            iterations = 0 #iterations for each learning rate
            learning_rate = 10**-4
        elif i == 2:
            print(f'\n\nTraining Pass {i+1}')
            time_slices = [time_slices[-1]]
            iterations = 0 #iterations for each learning rate
            learning_rate = 10**-4
        
        training_loop(net, time_slices, iterations, learning_rate, record_loss = 100, print_loss = 100, epsilon = epsilon)
        torch.save(net.state_dict(), f"{ctime}_Training_{i+1}.pt")
        partial_time_set[i] = time.time()
        np.savetxt(f"{ctime}epsilon_{i}.txt", epsilon)

    print("Total Time:\t", partial_time_set[-1]-start, '\nPass 1 Time:\t', partial_time_set[0]-start, 
          '\nPass 2 Time:\t', partial_time_set[1]-partial_time_set[0], '\nPass 3 Time:\t', partial_time_set[2]-partial_time_set[1])
   
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def exp_time_sample(collocation_pt_number, t_l, t_u, r):
    t_uni = np.random.uniform(0,1, size=(collocation_pt_number, 1))
    
    t = -np.log(1-t_uni+t_uni*np.exp(-r*(t_u-t_l)))/r
    
    return t
def training_loop(net, time_slices, iterations, learning_rate, record_loss, print_loss, epsilon):
    
    # Domain boundary values
    x_l = net.x1_l
    x_u = net.x1_u
    
    #time starts at 0, ends at upper bouund updated in time_slices
    t_l = 0

    #numbers of sampling collocation points on each part
    IC_collocation = int(512)
    BC_collocation = int(200)
    pde_collocation = int(10000)

    #sampler setting for LatinHypercube sampling
    IC_lh_sampler = qmc.LatinHypercube(d=1)
    BC_lh_sampler = qmc.LatinHypercube(d=1)
    PDE_lh_sampler = qmc.LatinHypercube(d=2)
    PDE_lh_sampler2 = qmc.LatinHypercube(d=2)
    
    #update the learning rate as defined
    for g in net.optimizer.param_groups:
        g['lr'] = learning_rate
    
    #Iterate over time slices
    for final_time in time_slices:
        with torch.autograd.no_grad():
            print("\n\nCurrent End Time:", final_time, "Current Learning Rate: ", get_lr(net.optimizer))  
        epoch = 0
        for epoch in range(1, iterations):

            ##Define input points with LatinHypercube sampling
            x_IC = x_l + (x_u-x_l) *IC_lh_sampler.random(n=IC_collocation).reshape(IC_collocation,1)
            t_IC = np.random.uniform(low=t_l, high=t_l, size=(IC_collocation,1))
            
            input_x_IC = Variable(torch.from_numpy(x_IC).float(), requires_grad=True).to(device)
            input_t_IC = Variable(torch.from_numpy(t_IC).float(), requires_grad=True).to(device)
            
            t_BC = t_l + (final_time-t_l) *BC_lh_sampler.random(n=BC_collocation).reshape(BC_collocation,1)
    
            input_t_BC = Variable(torch.from_numpy(t_BC).float(), requires_grad=True).to(device)
    
            x_domain = x_l + (x_u-x_l) *PDE_lh_sampler.random(n=pde_collocation)[:,0].reshape(pde_collocation,1)
            t_domain = t_l + (final_time-t_l) *PDE_lh_sampler.random(n=pde_collocation)[:,1].reshape(pde_collocation,1)
            #t_domain_exp = exp_time_sample(pde_collocation, t_l, final_time, r=10)
            
            input_x_domain = Variable(torch.from_numpy(x_domain).float(), requires_grad=True).to(device)
            input_t_domain = Variable(torch.from_numpy(t_domain).float(), requires_grad=True).to(device)
            #input_t_domain_exp = Variable(torch.from_numpy(t_domain_exp).float(), requires_grad=True).to(device)

            x_domain_r = x_l + (x_u-x_l) *PDE_lh_sampler2.random(n=pde_collocation)[:,0].reshape(pde_collocation,1)
            t_domain_r = t_l + (final_time-t_l) *PDE_lh_sampler2.random(n=pde_collocation)[:,1].reshape(pde_collocation,1)
            #t_domain_r_exp = exp_time_sample(pde_collocation, t_l, final_time, r=10)
            
            input_x_domain_r = Variable(torch.from_numpy(x_domain_r).float(), requires_grad=True).to(device)
            input_t_domain_r = Variable(torch.from_numpy(t_domain_r).float(), requires_grad=True).to(device)
            #input_t_domain_r_exp = Variable(torch.from_numpy(t_domain_r_exp).float(), requires_grad=True).to(device)
            
            for i in list(range(0, int(pde_collocation//32)+1)):
                # initialize gradients to zero
                net.optimizer.zero_grad()
                
                PDEloss_tensor= lossNSpde_rank(net, input_x_domain_r, input_t_domain_r)     
            
                sorted_tensor, indices = torch.sort(PDEloss_tensor.view(-1), descending=True)
                sorted_tensor = sorted_tensor.view(-1, 1)
            
                max_stad = sorted_tensor[int(pde_collocation/10)-1,0]
            
                PDEloss_picked = torch.where(PDEloss_tensor>=max_stad, PDEloss_tensor, 0)
                #x_domain_r = torch.where(PDEloss_tensor==PDEloss_picked, input_x_domain_r, 0)
                #t_domain_r = torch.where(PDEloss_tensor==PDEloss_picked, input_t_domain_r, 0)
            
                PDEloss_adaptive = lossNSpde(net, input_x_domain_r, input_t_domain_r)*10 #(torch.sum(PDEloss_picked**2)/(int(pde_collocation/10)))**.5

                #Loss computation
                u_IC_loss = lossIC(net, input_x_IC, input_t_IC) #, u_IC_loss_mesh
                mse_IC = u_IC_loss
            
                #Loss based on Boundary Condition (Containing No-Slip and Free-slip)
                mse_BC_u, mse_BC_u_x = lossBdry(net, input_t_BC) 
                mse_BC = mse_BC_u+ mse_BC_u_x 
            
                #Loss based on PDE
                AC_mse= lossNSpde(net, input_x_domain, input_t_domain) 
                mse_PDE = AC_mse #+ PDEloss_adaptive
        
                loss =  (mse_BC + 1000*mse_IC + mse_PDE )
        
                loss.backward()
            
            
                def closure():
                    return loss
            
                #Make Iterative Step
                net.optimizer.step() #net.optimizer.step(closure)
            
            
            # Gradient Norm Clipping
            #torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm = 1000, error_if_nonfinite=False) #note max norm is more art than science
            
            with torch.autograd.no_grad():
                if epoch == 1 or epoch% 2 == 0: #print_loss
                    print("\nIteration:", epoch, "\tTotal Loss:", loss.data)
                    #,"\tadaptive IC Loss2: ", mse_IC_a2.item() , "\tadaptive CH PDE Loss2: ", CH_a2.item()
                    print("\tIC Loss: ", mse_IC.item(),
                          "\t BC u Loss: ", mse_BC_u.item(), "\t BC u_x Loss: ", mse_BC_u_x.item(),
                          "\nAC PDE Loss: ", AC_mse.item(), "\tadaptive PDE Loss: ", PDEloss_adaptive.item()
                         ) 
                if epoch%3 == 0:
                    np.savetxt(f"{ctime}epsilon.txt", epsilon)
                    torch.save(net.state_dict(), f"lr{get_lr(net.optimizer)}_t{final_time}_{ctime}.pt")
                if epoch%2 == 0:
                    torch.save( torch.cat([input_x_IC, input_t_IC],axis=1), 'initial.pt')
                    torch.save( torch.cat([input_x_domain, input_t_domain],axis=1), 'domain_latin.pt')
                    torch.save(torch.cat([input_x_domain_r, input_t_domain_r],axis=1), 'adap_resample.pt')
        
                

create_network(load=True, loadfile = "lr0.001_t0.2_4_10_14h.pt")
# Out:
# Date of Today :  4  / 11
# Hour :  10
#
# Loading file was completed
#
# Training PDE
#
#
# Training Pass 1
#
#
# Current End Time: 0.3 Current Learning Rate:  0.001
#
# Iteration: 1 	Total Loss: tensor(8.2497)
# 	IC Loss:  7.697980208831723e-07 	 BC u Loss:  0.00012607264216057956 	 BC u_x Loss:  8.244525909423828
# AC PDE Loss:  0.004228364676237106 	adaptive PDE Loss:  0.04514322429895401
#
# Iteration: 2 	Total Loss: tensor(8.8880)
# 	IC Loss:  1.2690204584941966e-06 	 BC u Loss:  4.438910764292814e-05 	 BC u_x Loss:  8.884492874145508
# AC PDE Loss:  0.0021707089617848396 	adaptive PDE Loss:  0.02156858518719673
#
# Iteration: 4 	Total Loss: tensor(5.7793)
# 	IC Loss:  1.1187467862328049e-05 	 BC u Loss:  0.00013037052121944726 	 BC u_x Loss:  5.767087936401367
# AC PDE Loss:  0.0009353961795568466 	adaptive PDE Loss:  0.00910068117082119
#
# Iteration: 6 	Total Loss: tensor(1.8055)
# 	IC Loss:  4.093070060662285e-07 	 BC u Loss:  8.948654794949107e-06 	 BC u_x Loss:  1.80451238155365
# AC PDE Loss:  0.0006038296851329505 	adaptive PDE Loss:  0.007405675947666168
#
# Iteration: 8 	Total Loss: tensor(1.1712)
# 	IC Loss:  4.136570055379707e-07 	 BC u Loss:  2.5946094410755904e-06 	 BC u_x Loss:  1.1702210903167725
# AC PDE Loss:  0.000515382329467684 	adaptive PDE Loss:  0.005731194280087948
#
# Iteration: 10 	Total Loss: tensor(1.2924)
# 	IC Loss:  1.2237481314514298e-05 	 BC u Loss:  0.00011301635822746903 	 BC u_x Loss:  1.2796157598495483
# AC PDE Loss:  0.0004704489838331938 	adaptive PDE Loss:  0.005331010557711124
#
# Iteration: 12 	Total Loss: tensor(1.1704)
# 	IC Loss:  8.63754321471788e-05 	 BC u Loss:  0.0001093108658096753 	 BC u_x Loss:  1.0832996368408203
# AC PDE Loss:  0.000651760317850858 	adaptive PDE Loss:  0.006656000390648842
#
# Iteration: 14 	Total Loss: tensor(1.7374)
# 	IC Loss:  7.957984780659899e-05 	 BC u Loss:  0.0008387651178054512 	 BC u_x Loss:  1.6563878059387207
# AC PDE Loss:  0.0005599908763542771 	adaptive PDE Loss:  0.0057281735353171825
#
# Iteration: 16 	Total Loss: tensor(0.7676)
# 	IC Loss:  1.0696036952140275e-05 	 BC u Loss:  0.00023207208141684532 	 BC u_x Loss:  0.756316602230072
# AC PDE Loss:  0.00039024933357723057 	adaptive PDE Loss:  0.0041804322972893715
#
# Iteration: 18 	Total Loss: tensor(0.3978)
# 	IC Loss:  1.1739592082449235e-05 	 BC u Loss:  1.1234664270887151e-05 	 BC u_x Loss:  0.38568660616874695
# AC PDE Loss:  0.00040149083361029625 	adaptive PDE Loss:  0.004230435937643051
#
# Iteration: 20 	Total Loss: tensor(0.7535)
# 	IC Loss:  6.430281064240262e-05 	 BC u Loss:  1.1538075341377407e-05 	 BC u_x Loss:  0.6887702941894531
# AC PDE Loss:  0.0003996603190898895 	adaptive PDE Loss:  0.0040931543335318565
#
# Iteration: 22 	Total Loss: tensor(4.4337)
# 	IC Loss:  9.044864555107779e-07 	 BC u Loss:  8.62859178596409e-06 	 BC u_x Loss:  4.4316630363464355
# AC PDE Loss:  0.001098504289984703 	adaptive PDE Loss:  0.010950401425361633
#
# Iteration: 24 	Total Loss: tensor(2.5890)
# 	IC Loss:  1.444904910385958e-06 	 BC u Loss:  1.908844569697976e-05 	 BC u_x Loss:  2.586998701095581
# AC PDE Loss:  0.0005053850472904742 	adaptive PDE Loss:  0.005041027441620827
#
# Iteration: 26 	Total Loss: tensor(2.1262)
# 	IC Loss:  2.3167974632087862e-06 	 BC u Loss:  1.0648932402546052e-05 	 BC u_x Loss:  2.1235289573669434
# AC PDE Loss:  0.0003908033831976354 	adaptive PDE Loss:  0.004132878500968218
#
# Iteration: 28 	Total Loss: tensor(1.1059)
# 	IC Loss:  4.435034497873858e-06 	 BC u Loss:  5.012171823182143e-05 	 BC u_x Loss:  1.1010258197784424
# AC PDE Loss:  0.0003675069601740688 	adaptive PDE Loss:  0.0038571618497371674
#
# Iteration: 30 	Total Loss: tensor(0.6066)
# 	IC Loss:  1.6869233149918728e-05 	 BC u Loss:  4.3674685002770275e-05 	 BC u_x Loss:  0.5892227292060852
# AC PDE Loss:  0.00044454666203819215 	adaptive PDE Loss:  0.004330308176577091
#
# Iteration: 32 	Total Loss: tensor(0.5883)
# 	IC Loss:  3.0530468393408228e-06 	 BC u Loss:  6.970352842472494e-05 	 BC u_x Loss:  0.5848150253295898
# AC PDE Loss:  0.00034072191920131445 	adaptive PDE Loss:  0.0037034954875707626
#
# Iteration: 34 	Total Loss: tensor(0.3268)
# 	IC Loss:  1.0356578968639951e-05 	 BC u Loss:  0.0002179021539632231 	 BC u_x Loss:  0.31594258546829224
# AC PDE Loss:  0.0003172683354932815 	adaptive PDE Loss:  0.0035259767901152372
#
# Iteration: 36 	Total Loss: tensor(0.2733)
# 	IC Loss:  3.688940705615096e-05 	 BC u Loss:  0.00028852728428319097 	 BC u_x Loss:  0.23577465116977692
# AC PDE Loss:  0.0003605115052778274 	adaptive PDE Loss:  0.0040549361146986485
#
# Iteration: 38 	Total Loss: tensor(0.4055)
# 	IC Loss:  5.567429070651997e-06 	 BC u Loss:  9.033393325807992e-06 	 BC u_x Loss:  0.39955347776412964
# AC PDE Loss:  0.0004171301843598485 	adaptive PDE Loss:  0.0044219158589839935
#
# Iteration: 40 	Total Loss: tensor(0.9584)
# 	IC Loss:  0.0001914206222863868 	 BC u Loss:  0.00011880376405315474 	 BC u_x Loss:  0.7663652300834656
# AC PDE Loss:  0.00046464495244435966 	adaptive PDE Loss:  0.004789270926266909
#
# Iteration: 42 	Total Loss: tensor(21.4517)
# 	IC Loss:  9.5729342319828e-07 	 BC u Loss:  5.68081668461673e-06 	 BC u_x Loss:  21.44892120361328
# AC PDE Loss:  0.0018574119312688708 	adaptive PDE Loss:  0.020620759576559067
#
# Iteration: 44 	Total Loss: tensor(10.3605)
# 	IC Loss:  1.9004097339347936e-05 	 BC u Loss:  0.00032014294993132353 	 BC u_x Loss:  10.340249061584473
# AC PDE Loss:  0.0008786341641098261 	adaptive PDE Loss:  0.008774545975029469
#
# Iteration: 46 	Total Loss: tensor(5.8265)
# 	IC Loss:  7.053625381558959e-07 	 BC u Loss:  5.046835667599225e-06 	 BC u_x Loss:  5.825132846832275
# AC PDE Loss:  0.0006200220086611807 	adaptive PDE Loss:  0.006144382059574127
#
# Iteration: 48 	Total Loss: tensor(3.8355)
# 	IC Loss:  0.00032245792681351304 	 BC u Loss:  0.0010432451963424683 	 BC u_x Loss:  3.510979413986206
# AC PDE Loss:  0.0010234747314825654 	adaptive PDE Loss:  0.010015229694545269
#
# Iteration: 50 	Total Loss: tensor(1.5083)
# 	IC Loss:  1.9627052552095847e-06 	 BC u Loss:  1.624880314921029e-05 	 BC u_x Loss:  1.5059123039245605
# AC PDE Loss:  0.0004525755357462913 	adaptive PDE Loss:  0.0048634326085448265
#
# Iteration: 52 	Total Loss: tensor(1.2602)
# 	IC Loss:  6.512552772619529e-06 	 BC u Loss:  5.099776171846315e-05 	 BC u_x Loss:  1.2531867027282715
# AC PDE Loss:  0.00041333751869387925 	adaptive PDE Loss:  0.0044462718069553375
#
# Iteration: 54 	Total Loss: tensor(0.6099)
# 	IC Loss:  1.239853554579895e-05 	 BC u Loss:  2.2288859327090904e-05 	 BC u_x Loss:  0.5969981551170349
# AC PDE Loss:  0.000527734577190131 	adaptive PDE Loss:  0.005506719928234816
#
# Iteration: 56 	Total Loss: tensor(0.9661)
# 	IC Loss:  6.855035280750599e-06 	 BC u Loss:  9.590788977220654e-05 	 BC u_x Loss:  0.9587376117706299
# AC PDE Loss:  0.00036745061515830457 	adaptive PDE Loss:  0.0036291403230279684
#
# Iteration: 58 	Total Loss: tensor(1.0601)
# 	IC Loss:  0.00015544747293461114 	 BC u Loss:  0.0015937755815684795 	 BC u_x Loss:  0.9025680422782898
# AC PDE Loss:  0.000464314449345693 	adaptive PDE Loss:  0.0046421829611063
#
# Iteration: 60 	Total Loss: tensor(0.8689)
# 	IC Loss:  9.33430692384718e-06 	 BC u Loss:  3.6734087188960984e-05 	 BC u_x Loss:  0.8591682314872742
# AC PDE Loss:  0.0003581757191568613 	adaptive PDE Loss:  0.0037025855854153633
#
# Iteration: 62 	Total Loss: tensor(2.2762)
# 	IC Loss:  5.643431109092489e-07 	 BC u Loss:  2.300502274010796e-06 	 BC u_x Loss:  2.2752349376678467
# AC PDE Loss:  0.00037611048901453614 	adaptive PDE Loss:  0.00399611983448267
#
# Iteration: 64 	Total Loss: tensor(1.5516)
# 	IC Loss:  3.7728088500443846e-05 	 BC u Loss:  2.0719931853818707e-05 	 BC u_x Loss:  1.5133389234542847
# AC PDE Loss:  0.0005230937385931611 	adaptive PDE Loss:  0.005477433558553457
#
# Iteration: 66 	Total Loss: tensor(0.7163)
# 	IC Loss:  4.728366548079066e-05 	 BC u Loss:  0.0010553877800703049 	 BC u_x Loss:  0.667618989944458
# AC PDE Loss:  0.000366357242455706 	adaptive PDE Loss:  0.00407798308879137
#
# Iteration: 68 	Total Loss: tensor(1.0916)
# 	IC Loss:  7.688989171583671e-06 	 BC u Loss:  2.6654504836187698e-05 	 BC u_x Loss:  1.0835585594177246
# AC PDE Loss:  0.0003506389621179551 	adaptive PDE Loss:  0.003842369420453906
#
# Iteration: 70 	Total Loss: tensor(1.3534)
# 	IC Loss:  8.727060776436701e-05 	 BC u Loss:  2.01074180949945e-06 	 BC u_x Loss:  1.265669584274292
# AC PDE Loss:  0.00044087509741075337 	adaptive PDE Loss:  0.00560607947409153
#
# Iteration: 72 	Total Loss: tensor(0.9438)
# 	IC Loss:  6.821059650974348e-05 	 BC u Loss:  0.0005131813231855631 	 BC u_x Loss:  0.8745035529136658
# AC PDE Loss:  0.0005424860282801092 	adaptive PDE Loss:  0.00609587924554944
#
# Iteration: 74 	Total Loss: tensor(2.8159)
# 	IC Loss:  6.375550469783775e-07 	 BC u Loss:  2.565820750533021e-06 	 BC u_x Loss:  2.814918279647827
# AC PDE Loss:  0.0003871973603963852 	adaptive PDE Loss:  0.0044228993356227875
#
# Iteration: 76 	Total Loss: tensor(1.8664)
# 	IC Loss:  2.849209295163746e-06 	 BC u Loss:  2.3236911147250794e-05 	 BC u_x Loss:  1.8632233142852783
# AC PDE Loss:  0.0003450066433288157 	adaptive PDE Loss:  0.0037002121098339558
#
# Iteration: 78 	Total Loss: tensor(1.6479)
# 	IC Loss:  2.327490074094385e-05 	 BC u Loss:  0.0001057652771123685 	 BC u_x Loss:  1.6241108179092407
# AC PDE Loss:  0.0003779056132771075 	adaptive PDE Loss:  0.004247293807566166
#
# Iteration: 80 	Total Loss: tensor(0.9967)
# 	IC Loss:  6.733331701980205e-06 	 BC u Loss:  3.28665082633961e-05 	 BC u_x Loss:  0.9895851612091064
# AC PDE Loss:  0.00030678397160954773 	adaptive PDE Loss:  0.0037269198801368475
#
# Iteration: 82 	Total Loss: tensor(0.9993)
# 	IC Loss:  8.57041304698214e-05 	 BC u Loss:  0.001174413482658565 	 BC u_x Loss:  0.9121080636978149
# AC PDE Loss:  0.00032482462120242417 	adaptive PDE Loss:  0.0035832603462040424
#
# Iteration: 84 	Total Loss: tensor(1.1124)
# 	IC Loss:  2.5247145458706655e-05 	 BC u Loss:  0.0003457754501141608 	 BC u_x Loss:  1.0864644050598145
# AC PDE Loss:  0.0003219895879738033 	adaptive PDE Loss:  0.0036957855336368084
#
# Iteration: 86 	Total Loss: tensor(1.1144)
# 	IC Loss:  1.1035824172722641e-05 	 BC u Loss:  2.57579540630104e-06 	 BC u_x Loss:  1.103047251701355
# AC PDE Loss:  0.00034674283233471215 	adaptive PDE Loss:  0.003741092747077346
#
# Iteration: 88 	Total Loss: tensor(1.1551)
# 	IC Loss:  9.832510841079056e-05 	 BC u Loss:  0.0004566475690808147 	 BC u_x Loss:  1.0558059215545654
# AC PDE Loss:  0.0005042545963078737 	adaptive PDE Loss:  0.005830992013216019
#
# Iteration: 90 	Total Loss: tensor(0.2640)
# 	IC Loss:  1.7832009007179295e-06 	 BC u Loss:  1.4249467312765773e-05 	 BC u_x Loss:  0.25993314385414124
# AC PDE Loss:  0.002260692184790969 	adaptive PDE Loss:  0.023311350494623184
#
# Iteration: 92 	Total Loss: tensor(4.1528)
# 	IC Loss:  5.188188652027748e-07 	 BC u Loss:  1.6087351468740962e-06 	 BC u_x Loss:  4.151838779449463
# AC PDE Loss:  0.0004428375686984509 	adaptive PDE Loss:  0.00422278605401516
#
# Iteration: 94 	Total Loss: tensor(4.1534)
# 	IC Loss:  4.747835919260979e-05 	 BC u Loss:  9.322574442194309e-06 	 BC u_x Loss:  4.105136871337891
# AC PDE Loss:  0.0007448462420143187 	adaptive PDE Loss:  0.008165829814970493
#
# Iteration: 96 	Total Loss: tensor(3.0072)
# 	IC Loss:  0.00026212885859422386 	 BC u Loss:  1.0219385330856312e-05 	 BC u_x Loss:  2.744513511657715
# AC PDE Loss:  0.0005497251404449344 	adaptive PDE Loss:  0.005815048702061176
#
# Iteration: 98 	Total Loss: tensor(2.5822)
# 	IC Loss:  9.602408681530505e-05 	 BC u Loss:  0.0009329552995041013 	 BC u_x Loss:  2.4848968982696533
# AC PDE Loss:  0.0003944338532164693 	adaptive PDE Loss:  0.003852978115901351
#
#
# Current End Time: 0.4 Current Learning Rate:  0.001
#
# Iteration: 1 	Total Loss: tensor(27.5685)
# 	IC Loss:  3.125244575130637e-06 	 BC u Loss:  9.270088048651814e-05 	 BC u_x Loss:  27.56415367126465
# AC PDE Loss:  0.0010852004634216428 	adaptive PDE Loss:  0.011624474078416824
#
# Iteration: 2 	Total Loss: tensor(29.8924)
# 	IC Loss:  6.649222632404417e-05 	 BC u Loss:  0.0010557034984230995 	 BC u_x Loss:  29.823984146118164
# AC PDE Loss:  0.0009006065083667636 	adaptive PDE Loss:  0.009487665258347988
#
# Iteration: 4 	Total Loss: tensor(23.5297)
# 	IC Loss:  4.954560154146748e-06 	 BC u Loss:  3.6446474496187875e-06 	 BC u_x Loss:  23.524124145507812
# AC PDE Loss:  0.0006586398812942207 	adaptive PDE Loss:  0.006869331002235413
#
# Iteration: 6 	Total Loss: tensor(21.8349)
# 	IC Loss:  4.157992225373164e-05 	 BC u Loss:  0.0005862971302121878 	 BC u_x Loss:  21.7921142578125
# AC PDE Loss:  0.0006036770646460354 	adaptive PDE Loss:  0.006586558185517788
#
# Iteration: 8 	Total Loss: tensor(18.3947)
# 	IC Loss:  2.8851138267782517e-05 	 BC u Loss:  3.1476025469601154e-05 	 BC u_x Loss:  18.36530876159668
# AC PDE Loss:  0.0005535534583032131 	adaptive PDE Loss:  0.0066087390296161175
#
# Iteration: 10 	Total Loss: tensor(17.4579)
# 	IC Loss:  0.0001173421842395328 	 BC u Loss:  0.0032872301526367664 	 BC u_x Loss:  17.336658477783203
# AC PDE Loss:  0.0005648910300806165 	adaptive PDE Loss:  0.0067445142194628716
#
# Iteration: 12 	Total Loss: tensor(38.3231)
# 	IC Loss:  5.123849859955953e-07 	 BC u Loss:  7.042582183203194e-06 	 BC u_x Loss:  38.3209228515625
# AC PDE Loss:  0.0016469573602080345 	adaptive PDE Loss:  0.01768261380493641
#
# Iteration: 14 	Total Loss: tensor(52.0110)
# 	IC Loss:  6.148888587631518e-06 	 BC u Loss:  0.00021737540373578668 	 BC u_x Loss:  52.0035285949707
# AC PDE Loss:  0.0011006713612005115 	adaptive PDE Loss:  0.01149079017341137
#
# Iteration: 16 	Total Loss: tensor(33.2392)
# 	IC Loss:  0.00045284078805707395 	 BC u Loss:  0.0034062222111970186 	 BC u_x Loss:  32.78166961669922
# AC PDE Loss:  0.0012878229608759284 	adaptive PDE Loss:  0.013351337984204292
#
# Iteration: 18 	Total Loss: tensor(26.7775)
# 	IC Loss:  0.0008440901292487979 	 BC u Loss:  0.00019516913744155318 	 BC u_x Loss:  25.931493759155273
# AC PDE Loss:  0.0016817726427689195 	adaptive PDE Loss:  0.01774299144744873
#
# Iteration: 20 	Total Loss: tensor(20.0673)
# 	IC Loss:  7.277099939528853e-06 	 BC u Loss:  8.022935799090192e-05 	 BC u_x Loss:  20.0593318939209
# AC PDE Loss:  0.0006094370037317276 	adaptive PDE Loss:  0.007156532257795334
#
# Iteration: 22 	Total Loss: tensor(23.0637)
# 	IC Loss:  0.0003675188054330647 	 BC u Loss:  0.0007824522326700389 	 BC u_x Loss:  22.694360733032227
# AC PDE Loss:  0.0009879922727122903 	adaptive PDE Loss:  0.010196389630436897
#
# Iteration: 24 	Total Loss: tensor(19.8937)
# 	IC Loss:  4.170778083789628e-06 	 BC u Loss:  0.00010352306708227843 	 BC u_x Loss:  19.888893127441406
# AC PDE Loss:  0.0004971764283254743 	adaptive PDE Loss:  0.005748404189944267
#
# Iteration: 26 	Total Loss: tensor(18.5349)
# 	IC Loss:  1.8553082554717548e-05 	 BC u Loss:  0.000567279988899827 	 BC u_x Loss:  18.515338897705078
# AC PDE Loss:  0.00046047219075262547 	adaptive PDE Loss:  0.005199532024562359
#
# Iteration: 28 	Total Loss: tensor(17.3322)
# 	IC Loss:  0.0001437525061191991 	 BC u Loss:  3.733547782758251e-05 	 BC u_x Loss:  17.187650680541992
# AC PDE Loss:  0.0008054805803112686 	adaptive PDE Loss:  0.009299674071371555
#
# Iteration: 30 	Total Loss: tensor(16.8793)
# 	IC Loss:  0.00045115555985830724 	 BC u Loss:  0.0006650213617831469 	 BC u_x Loss:  16.426416397094727
# AC PDE Loss:  0.0010571508901193738 	adaptive PDE Loss:  0.010858862660825253
#
# Iteration: 32 	Total Loss: tensor(47.5080)
# 	IC Loss:  4.141621730013867e-07 	 BC u Loss:  3.169566980432137e-06 	 BC u_x Loss:  47.506839752197266
# AC PDE Loss:  0.0007020735065452754 	adaptive PDE Loss:  0.006637503392994404
#
# Iteration: 34 	Total Loss: tensor(31.8659)
# 	IC Loss:  0.00010640778782544658 	 BC u Loss:  8.509340659657028e-06 	 BC u_x Loss:  31.75890350341797
# AC PDE Loss:  0.0005495974328368902 	adaptive PDE Loss:  0.006040194537490606
#
# Iteration: 36 	Total Loss: tensor(21.5498)
# 	IC Loss:  7.437755016326264e-07 	 BC u Loss:  2.9799912226735614e-06 	 BC u_x Loss:  21.548643112182617
# AC PDE Loss:  0.0004392388218548149 	adaptive PDE Loss:  0.004520860500633717
#
# Iteration: 38 	Total Loss: tensor(22.2627)
# 	IC Loss:  6.456576375057921e-05 	 BC u Loss:  0.00028916902374476194 	 BC u_x Loss:  22.197359085083008
# AC PDE Loss:  0.00045598470023833215 	adaptive PDE Loss:  0.005302634090185165
#
# Iteration: 40 	Total Loss: tensor(10.6791)
# 	IC Loss:  1.4066921721678227e-05 	 BC u Loss:  1.8973267287947237e-05 	 BC u_x Loss:  10.664546012878418
# AC PDE Loss:  0.000476419780170545 	adaptive PDE Loss:  0.005109335295855999
#
# Iteration: 42 	Total Loss: tensor(14.5630)
# 	IC Loss:  4.035930760437623e-05 	 BC u Loss:  0.0008024690905585885 	 BC u_x Loss:  14.52140998840332
# AC PDE Loss:  0.0004218062967993319 	adaptive PDE Loss:  0.0044746603816747665
#
# Iteration: 44 	Total Loss: tensor(13.4952)
# 	IC Loss:  1.200709357362939e-05 	 BC u Loss:  1.4569295672117732e-06 	 BC u_x Loss:  13.482807159423828
# AC PDE Loss:  0.0003620578208938241 	adaptive PDE Loss:  0.005051050800830126
#
# Iteration: 46 	Total Loss: tensor(20.8646)
# 	IC Loss:  4.4625920736507396e-07 	 BC u Loss:  1.262672867596848e-06 	 BC u_x Loss:  20.863597869873047
# AC PDE Loss:  0.0005229666130617261 	adaptive PDE Loss:  0.005372154992073774
#
# Iteration: 48 	Total Loss: tensor(17.1399)
# 	IC Loss:  3.13292839564383e-05 	 BC u Loss:  0.000730356143321842 	 BC u_x Loss:  17.107498168945312
# AC PDE Loss:  0.0003800808044616133 	adaptive PDE Loss:  0.004067396745085716
#
# Iteration: 50 	Total Loss: tensor(13.9110)
# 	IC Loss:  2.1913247110205702e-05 	 BC u Loss:  9.798487735679373e-05 	 BC u_x Loss:  13.888579368591309
# AC PDE Loss:  0.0003899617586284876 	adaptive PDE Loss:  0.004672627430409193
#
# Iteration: 52 	Total Loss: tensor(11.7999)
# 	IC Loss:  2.8942353310412727e-05 	 BC u Loss:  4.476416961551877e-06 	 BC u_x Loss:  11.770371437072754
# AC PDE Loss:  0.0005437427316792309 	adaptive PDE Loss:  0.005576701369136572
#
# Iteration: 54 	Total Loss: tensor(14.7898)
# 	IC Loss:  2.184249933634419e-05 	 BC u Loss:  0.00013209595635998994 	 BC u_x Loss:  14.767470359802246
# AC PDE Loss:  0.0003932566032744944 	adaptive PDE Loss:  0.005661850795149803
#
# Iteration: 56 	Total Loss: tensor(13.8173)
# 	IC Loss:  3.3814325206549256e-07 	 BC u Loss:  1.3006174413021654e-06 	 BC u_x Loss:  13.816598892211914
# AC PDE Loss:  0.0003701046807691455 	adaptive PDE Loss:  0.004607889335602522
#
# Iteration: 58 	Total Loss: tensor(16.8897)
# 	IC Loss:  3.856900093524018e-06 	 BC u Loss:  2.4002920326893218e-06 	 BC u_x Loss:  16.885530471801758
# AC PDE Loss:  0.0003360487171448767 	adaptive PDE Loss:  0.004091220907866955
#
# Iteration: 60 	Total Loss: tensor(12.7112)
# 	IC Loss:  4.127984993829159e-06 	 BC u Loss:  6.2850594986230135e-06 	 BC u_x Loss:  12.706659317016602
# AC PDE Loss:  0.0004358872538432479 	adaptive PDE Loss:  0.005279547069221735
#
# Iteration: 62 	Total Loss: tensor(13.6028)
# 	IC Loss:  0.00013998456415720284 	 BC u Loss:  0.002192546147853136 	 BC u_x Loss:  13.460125923156738
# AC PDE Loss:  0.0005055910442024469 	adaptive PDE Loss:  0.006501948460936546
#
# Iteration: 64 	Total Loss: tensor(17.0725)
# 	IC Loss:  6.020429736963706e-07 	 BC u Loss:  3.415678747842321e-06 	 BC u_x Loss:  17.071208953857422
# AC PDE Loss:  0.0007124327239580452 	adaptive PDE Loss:  0.007782529573887587
#
# Iteration: 66 	Total Loss: tensor(17.1184)
# 	IC Loss:  4.2426322011124284e-07 	 BC u Loss:  1.1572514040381066e-06 	 BC u_x Loss:  17.117502212524414
# AC PDE Loss:  0.0004393286653794348 	adaptive PDE Loss:  0.004161251243203878
#
# Iteration: 68 	Total Loss: tensor(20.3747)
# 	IC Loss:  1.1955687114095781e-05 	 BC u Loss:  0.00010240664414595813 	 BC u_x Loss:  20.362165451049805
# AC PDE Loss:  0.00048658318701200187 	adaptive PDE Loss:  0.004875407554209232
#
# Iteration: 70 	Total Loss: tensor(17.7584)
# 	IC Loss:  1.092487650566909e-06 	 BC u Loss:  5.6610751926200464e-06 	 BC u_x Loss:  17.75682830810547
# AC PDE Loss:  0.0005082186544314027 	adaptive PDE Loss:  0.0053605493158102036
#
# Iteration: 72 	Total Loss: tensor(15.5116)
# 	IC Loss:  8.266458735306514e-07 	 BC u Loss:  8.251508916146122e-06 	 BC u_x Loss:  15.510318756103516
# AC PDE Loss:  0.00041494378820061684 	adaptive PDE Loss:  0.004467053338885307
#
# Iteration: 74 	Total Loss: tensor(15.9354)
# 	IC Loss:  4.415298008098034e-06 	 BC u Loss:  9.414966916665435e-05 	 BC u_x Loss:  15.93046760559082
# AC PDE Loss:  0.00045818090438842773 	adaptive PDE Loss:  0.0052260044030845165
#
# Iteration: 76 	Total Loss: tensor(14.3286)
# 	IC Loss:  0.0001484167732996866 	 BC u Loss:  0.00258191442117095 	 BC u_x Loss:  14.177088737487793
# AC PDE Loss:  0.00048061570851132274 	adaptive PDE Loss:  0.005702268332242966
#
# Iteration: 78 	Total Loss: tensor(16.8475)
# 	IC Loss:  2.1753319742856547e-05 	 BC u Loss:  0.0004934422904625535 	 BC u_x Loss:  16.824878692626953
# AC PDE Loss:  0.00039430137258023024 	adaptive PDE Loss:  0.004647589288651943
#
# Iteration: 80 	Total Loss: tensor(18.7591)
# 	IC Loss:  6.657509402430151e-06 	 BC u Loss:  5.168290954316035e-05 	 BC u_x Loss:  18.751981735229492
# AC PDE Loss:  0.00038168474566191435 	adaptive PDE Loss:  0.004068717360496521
#
# Iteration: 82 	Total Loss: tensor(16.0785)
# 	IC Loss:  7.171189645305276e-05 	 BC u Loss:  0.00034592009615153074 	 BC u_x Loss:  16.00585174560547
# AC PDE Loss:  0.0005462642875500023 	adaptive PDE Loss:  0.006594962440431118
#
# Iteration: 84 	Total Loss: tensor(20.9485)
# 	IC Loss:  2.6999685360351577e-05 	 BC u Loss:  9.690941078588367e-05 	 BC u_x Loss:  20.920961380004883
# AC PDE Loss:  0.00042518324335105717 	adaptive PDE Loss:  0.004623686894774437
#
# Iteration: 86 	Total Loss: tensor(1.5298)
# 	IC Loss:  5.248429602033866e-07 	 BC u Loss:  4.5805882109561935e-06 	 BC u_x Loss:  1.528495192527771
# AC PDE Loss:  0.0007476913742721081 	adaptive PDE Loss:  0.008679310791194439
#
# Iteration: 88 	Total Loss: tensor(12.5249)
# 	IC Loss:  1.0287195664204773e-06 	 BC u Loss:  2.73651512543438e-05 	 BC u_x Loss:  12.523386001586914
# AC PDE Loss:  0.0004759799048770219 	adaptive PDE Loss:  0.00554441474378109
#
# Iteration: 90 	Total Loss: tensor(13.2744)
# 	IC Loss:  1.8000673662754707e-05 	 BC u Loss:  0.00021170760737732053 	 BC u_x Loss:  13.255698204040527
# AC PDE Loss:  0.00046278900117613375 	adaptive PDE Loss:  0.004995938390493393
#
# Iteration: 92 	Total Loss: tensor(15.3536)
# 	IC Loss:  1.6887773881535395e-06 	 BC u Loss:  9.548227808409138e-07 	 BC u_x Loss:  15.351476669311523
# AC PDE Loss:  0.00046540884068235755 	adaptive PDE Loss:  0.005240746773779392
#
# Iteration: 94 	Total Loss: tensor(14.3647)
# 	IC Loss:  5.482123015099205e-06 	 BC u Loss:  1.150275238614995e-05 	 BC u_x Loss:  14.358770370483398
# AC PDE Loss:  0.000472374667879194 	adaptive PDE Loss:  0.005230392329394817
#
# Iteration: 96 	Total Loss: tensor(14.8709)
# 	IC Loss:  4.805771095561795e-05 	 BC u Loss:  0.0017430820735171437 	 BC u_x Loss:  14.82073974609375
# AC PDE Loss:  0.00040504918433725834 	adaptive PDE Loss:  0.00449744239449501
#
# Iteration: 98 	Total Loss: tensor(14.4369)
# 	IC Loss:  1.749195871525444e-05 	 BC u Loss:  1.7683049009065144e-05 	 BC u_x Loss:  14.41882038116455
# AC PDE Loss:  0.0005231816903688014 	adaptive PDE Loss:  0.006499293260276318
#
#
# Current End Time: 0.5 Current Learning Rate:  0.001
#
# Iteration: 1 	Total Loss: tensor(31.5987)
# 	IC Loss:  2.4624974685139023e-05 	 BC u Loss:  0.00014111195923760533 	 BC u_x Loss:  31.572206497192383
# AC PDE Loss:  0.0017341694328933954 	adaptive PDE Loss:  0.019979970529675484
#
# Iteration: 2 	Total Loss: tensor(47.2383)
# 	IC Loss:  5.9299159147485625e-06 	 BC u Loss:  0.00023045795387588441 	 BC u_x Loss:  47.23088073730469
# AC PDE Loss:  0.0012320863315835595 	adaptive PDE Loss:  0.013970773667097092
#
# Iteration: 4 	Total Loss: tensor(55.8690)
# 	IC Loss:  1.899596827570349e-05 	 BC u Loss:  0.00019507957040332258 	 BC u_x Loss:  55.84877395629883
# AC PDE Loss:  0.0010609491728246212 	adaptive PDE Loss:  0.011053914204239845
#
# Iteration: 6 	Total Loss: tensor(70.5971)
# 	IC Loss:  3.6188743251841515e-05 	 BC u Loss:  3.559354809112847e-05 	 BC u_x Loss:  70.56002807617188
# AC PDE Loss:  0.0008928672759793699 	adaptive PDE Loss:  0.009441722184419632
#
# Iteration: 8 	Total Loss: tensor(71.1246)
# 	IC Loss:  7.565351552329957e-05 	 BC u Loss:  0.0012387947645038366 	 BC u_x Loss:  71.04674530029297
# AC PDE Loss:  0.0009223040542565286 	adaptive PDE Loss:  0.01051720604300499
#
# Iteration: 10 	Total Loss: tensor(64.1355)
# 	IC Loss:  5.824065283377422e-07 	 BC u Loss:  3.105959422100568e-06 	 BC u_x Loss:  64.13398742675781
# AC PDE Loss:  0.0008838516077958047 	adaptive PDE Loss:  0.00988861545920372
#
# Iteration: 12 	Total Loss: tensor(88.6453)
# 	IC Loss:  2.0592826786014484e-06 	 BC u Loss:  5.8383753639645875e-05 	 BC u_x Loss:  88.64269256591797
# AC PDE Loss:  0.0005279884207993746 	adaptive PDE Loss:  0.00669834204018116
#
# Iteration: 14 	Total Loss: tensor(79.7815)
# 	IC Loss:  8.303749154947582e-07 	 BC u Loss:  2.993624184455257e-05 	 BC u_x Loss:  79.78018951416016
# AC PDE Loss:  0.0004605694848578423 	adaptive PDE Loss:  0.0070550162345170975
#
# Iteration: 16 	Total Loss: tensor(68.4273)
# 	IC Loss:  0.0001600528776179999 	 BC u Loss:  0.0006441278965212405 	 BC u_x Loss:  68.26580810546875
# AC PDE Loss:  0.0008138298289850354 	adaptive PDE Loss:  0.008442772552371025
#
# Iteration: 18 	Total Loss: tensor(75.9202)
# 	IC Loss:  8.580620942666428e-07 	 BC u Loss:  2.1450961867230944e-05 	 BC u_x Loss:  75.91889190673828
# AC PDE Loss:  0.0004209856560919434 	adaptive PDE Loss:  0.005437072366476059
#
# Iteration: 20 	Total Loss: tensor(56.4301)
# 	IC Loss:  3.96883551729843e-05 	 BC u Loss:  0.0009635654278099537 	 BC u_x Loss:  56.388797760009766
# AC PDE Loss:  0.0006458109128288925 	adaptive PDE Loss:  0.006488478276878595
#
# Iteration: 22 	Total Loss: tensor(86.2748)
# 	IC Loss:  0.0006809949409216642 	 BC u Loss:  0.0003324821882415563 	 BC u_x Loss:  85.59222412109375
# AC PDE Loss:  0.0012721195816993713 	adaptive PDE Loss:  0.013653375208377838
#
# Iteration: 24 	Total Loss: tensor(72.3151)
# 	IC Loss:  5.637453455165087e-07 	 BC u Loss:  5.398836037784349e-06 	 BC u_x Loss:  72.31394958496094
# AC PDE Loss:  0.0006143636419437826 	adaptive PDE Loss:  0.006888219155371189
#
# Iteration: 26 	Total Loss: tensor(93.8880)
# 	IC Loss:  3.865378630507621e-07 	 BC u Loss:  2.3387601686408743e-06 	 BC u_x Loss:  93.88725280761719
# AC PDE Loss:  0.0003578893665689975 	adaptive PDE Loss:  0.004720406141132116
#
# Iteration: 28 	Total Loss: tensor(62.6617)
# 	IC Loss:  1.634353793633636e-05 	 BC u Loss:  3.638431735453196e-05 	 BC u_x Loss:  62.64466857910156
# AC PDE Loss:  0.0006946487701497972 	adaptive PDE Loss:  0.006875242106616497
#
# Iteration: 30 	Total Loss: tensor(81.8877)
# 	IC Loss:  3.021456541318912e-05 	 BC u Loss:  1.3123022654326633e-05 	 BC u_x Loss:  81.85708618164062
# AC PDE Loss:  0.00039011501939967275 	adaptive PDE Loss:  0.005136840045452118
#
# Iteration: 32 	Total Loss: tensor(75.0090)
# 	IC Loss:  9.570427937433124e-05 	 BC u Loss:  0.0028995410539209843 	 BC u_x Loss:  74.90994262695312
# AC PDE Loss:  0.0005033283377997577 	adaptive PDE Loss:  0.0057399156503379345
#
# Iteration: 34 	Total Loss: tensor(77.9272)
# 	IC Loss:  8.120032362057827e-06 	 BC u Loss:  8.709250323590823e-06 	 BC u_x Loss:  77.91869354248047
# AC PDE Loss:  0.000379285920644179 	adaptive PDE Loss:  0.005068330094218254
#
# Iteration: 36 	Total Loss: tensor(68.7891)
# 	IC Loss:  0.00024377863155677915 	 BC u Loss:  0.0018274171743541956 	 BC u_x Loss:  68.54220581054688
# AC PDE Loss:  0.001330922357738018 	adaptive PDE Loss:  0.015312024392187595
#
# Iteration: 38 	Total Loss: tensor(101.7360)
# 	IC Loss:  6.581204843314481e-07 	 BC u Loss:  1.602404154255055e-05 	 BC u_x Loss:  101.73445129394531
# AC PDE Loss:  0.0009160757181234658 	adaptive PDE Loss:  0.010544482618570328
#
# Iteration: 40 	Total Loss: tensor(88.4089)
# 	IC Loss:  4.7381507783939014e-07 	 BC u Loss:  1.681668095443456e-06 	 BC u_x Loss:  88.40789031982422
# AC PDE Loss:  0.000516655680257827 	adaptive PDE Loss:  0.005544053390622139
#
# Iteration: 42 	Total Loss: tensor(76.1479)
# 	IC Loss:  3.8702050915162545e-06 	 BC u Loss:  3.907842256012373e-06 	 BC u_x Loss:  76.1435317993164
# AC PDE Loss:  0.0005452372715808451 	adaptive PDE Loss:  0.00634451350197196
#
# Iteration: 44 	Total Loss: tensor(81.6958)
# 	IC Loss:  0.0007619228563271463 	 BC u Loss:  0.0002605960762593895 	 BC u_x Loss:  80.93219757080078
# AC PDE Loss:  0.0013860960025340319 	adaptive PDE Loss:  0.014887006022036076
#
# Iteration: 46 	Total Loss: tensor(69.0826)
# 	IC Loss:  7.583050319226459e-05 	 BC u Loss:  0.001356118475086987 	 BC u_x Loss:  69.00497436523438
# AC PDE Loss:  0.0004411498666740954 	adaptive PDE Loss:  0.00528052169829607
#
# Iteration: 48 	Total Loss: tensor(63.7663)
# 	IC Loss:  1.0345753253204748e-05 	 BC u Loss:  5.8338005146651994e-06 	 BC u_x Loss:  63.7553596496582
# AC PDE Loss:  0.0005471428739838302 	adaptive PDE Loss:  0.00552234286442399
#
# Iteration: 50 	Total Loss: tensor(76.5319)
# 	IC Loss:  6.5603530856606085e-06 	 BC u Loss:  6.798008143960033e-06 	 BC u_x Loss:  76.52489471435547
# AC PDE Loss:  0.00044637604150921106 	adaptive PDE Loss:  0.00478353863582015
#
# Iteration: 52 	Total Loss: tensor(73.5740)
# 	IC Loss:  0.0003011919616255909 	 BC u Loss:  4.001435445388779e-05 	 BC u_x Loss:  73.27198028564453
# AC PDE Loss:  0.0007536030025221407 	adaptive PDE Loss:  0.009819180704653263
#
# Iteration: 54 	Total Loss: tensor(65.4221)
# 	IC Loss:  5.3194929932942614e-05 	 BC u Loss:  0.0029911540914326906 	 BC u_x Loss:  65.3655014038086
# AC PDE Loss:  0.0003829564666375518 	adaptive PDE Loss:  0.005119486711919308
#
# Iteration: 56 	Total Loss: tensor(75.3111)
# 	IC Loss:  1.4272600310505368e-06 	 BC u Loss:  5.584058271779213e-06 	 BC u_x Loss:  75.3093032836914
# AC PDE Loss:  0.00033028022153303027 	adaptive PDE Loss:  0.004394460003823042
#
# Iteration: 58 	Total Loss: tensor(90.3302)
# 	IC Loss:  1.4617704664487974e-06 	 BC u Loss:  8.358350169146433e-05 	 BC u_x Loss:  90.3283462524414
# AC PDE Loss:  0.00030399480601772666 	adaptive PDE Loss:  0.00413773488253355
#
# Iteration: 60 	Total Loss: tensor(85.6481)
# 	IC Loss:  5.994836556055816e-07 	 BC u Loss:  3.5454525004752213e-06 	 BC u_x Loss:  85.64717102050781
# AC PDE Loss:  0.0003431054938118905 	adaptive PDE Loss:  0.005271569825708866
#
# Iteration: 62 	Total Loss: tensor(79.7275)
# 	IC Loss:  0.00012004402378806844 	 BC u Loss:  6.676829798379913e-06 	 BC u_x Loss:  79.60692596435547
# AC PDE Loss:  0.0005196376005187631 	adaptive PDE Loss:  0.006678850390017033
#
# Iteration: 64 	Total Loss: tensor(65.2030)
# 	IC Loss:  1.1256772268097848e-05 	 BC u Loss:  0.0002286584349349141 	 BC u_x Loss:  65.1910629272461
# AC PDE Loss:  0.0004153636400587857 	adaptive PDE Loss:  0.006414802744984627
#
# Iteration: 66 	Total Loss: tensor(69.5569)
# 	IC Loss:  6.147451131255366e-06 	 BC u Loss:  1.3993870197737124e-05 	 BC u_x Loss:  69.55035400390625
# AC PDE Loss:  0.0004008030518889427 	adaptive PDE Loss:  0.006402965635061264
#
# Iteration: 68 	Total Loss: tensor(42.4981)
# 	IC Loss:  0.0007287494372576475 	 BC u Loss:  0.0007454558508470654 	 BC u_x Loss:  41.7392463684082
# AC PDE Loss:  0.029314151033759117 	adaptive PDE Loss:  0.3344252407550812
#
# Iteration: 70 	Total Loss: tensor(63.2501)
# 	IC Loss:  6.423020977308624e-07 	 BC u Loss:  4.998582426196663e-06 	 BC u_x Loss:  63.24903869628906
# AC PDE Loss:  0.0003933721163775772 	adaptive PDE Loss:  0.005103330593556166
#
# Iteration: 72 	Total Loss: tensor(78.7545)
# 	IC Loss:  2.34175627156219e-06 	 BC u Loss:  2.836894964275416e-06 	 BC u_x Loss:  78.7516860961914
# AC PDE Loss:  0.0004253927618265152 	adaptive PDE Loss:  0.005865453742444515
#
# Iteration: 74 	Total Loss: tensor(73.3579)
# 	IC Loss:  6.718505028402433e-05 	 BC u Loss:  3.953913983423263e-05 	 BC u_x Loss:  73.2902603149414
# AC PDE Loss:  0.00045252314885146916 	adaptive PDE Loss:  0.005983877927064896
#
# Iteration: 76 	Total Loss: tensor(73.8044)
# 	IC Loss:  8.550839993404225e-06 	 BC u Loss:  0.0002736587484832853 	 BC u_x Loss:  73.79527282714844
# AC PDE Loss:  0.00033771857852116227 	adaptive PDE Loss:  0.004692594055086374
#
# Iteration: 78 	Total Loss: tensor(67.9313)
# 	IC Loss:  7.783160253893584e-05 	 BC u Loss:  0.00022621270909439772 	 BC u_x Loss:  67.85271453857422
# AC PDE Loss:  0.0004750061489176005 	adaptive PDE Loss:  0.006893296726047993
#
# Iteration: 80 	Total Loss: tensor(76.7918)
# 	IC Loss:  4.926965175400255e-06 	 BC u Loss:  0.000197863788343966 	 BC u_x Loss:  76.78638458251953
# AC PDE Loss:  0.00032228423515334725 	adaptive PDE Loss:  0.004496108274906874
#
# Iteration: 82 	Total Loss: tensor(94.8935)
# 	IC Loss:  4.056777243022225e-07 	 BC u Loss:  1.5359479448306956e-06 	 BC u_x Loss:  94.89278411865234
# AC PDE Loss:  0.00034862104803323746 	adaptive PDE Loss:  0.005153577774763107
#
# Iteration: 84 	Total Loss: tensor(77.6775)
# 	IC Loss:  6.409170055121649e-06 	 BC u Loss:  5.974182386125904e-06 	 BC u_x Loss:  77.6706771850586
# AC PDE Loss:  0.00035648266202770174 	adaptive PDE Loss:  0.006866948679089546
#
# Iteration: 86 	Total Loss: tensor(96.9984)
# 	IC Loss:  1.0687655958463438e-05 	 BC u Loss:  6.0183723689988256e-05 	 BC u_x Loss:  96.98727416992188
# AC PDE Loss:  0.00041469992720521986 	adaptive PDE Loss:  0.006624529138207436
#
# Iteration: 88 	Total Loss: tensor(77.3427)
# 	IC Loss:  0.0005963196745142341 	 BC u Loss:  0.0029756235890090466 	 BC u_x Loss:  76.74224853515625
# AC PDE Loss:  0.0011554713128134608 	adaptive PDE Loss:  0.012472397647798061
#
# Iteration: 90 	Total Loss: tensor(65.0506)
# 	IC Loss:  2.062992462015245e-05 	 BC u Loss:  0.00012824668374378234 	 BC u_x Loss:  65.02947235107422
# AC PDE Loss:  0.0004120448138564825 	adaptive PDE Loss:  0.005060745403170586
#
# Iteration: 92 	Total Loss: tensor(69.9935)
# 	IC Loss:  0.0005660058814100921 	 BC u Loss:  0.000622484483756125 	 BC u_x Loss:  69.42578125
# AC PDE Loss:  0.0011327012907713652 	adaptive PDE Loss:  0.013786016032099724
#
# Iteration: 94 	Total Loss: tensor(73.7090)
# 	IC Loss:  3.726807335624471e-05 	 BC u Loss:  0.0021856590174138546 	 BC u_x Loss:  73.66914367675781
# AC PDE Loss:  0.0003989430551882833 	adaptive PDE Loss:  0.006800221279263496
#
# Iteration: 96 	Total Loss: tensor(88.4168)
# 	IC Loss:  8.661228889650374e-07 	 BC u Loss:  5.677689387084683e-06 	 BC u_x Loss:  88.41493225097656
# AC PDE Loss:  0.000961245154030621 	adaptive PDE Loss:  0.01338900439441204
#
# Iteration: 98 	Total Loss: tensor(122.7987)
# 	IC Loss:  4.3086677692372177e-07 	 BC u Loss:  3.284725607954897e-06 	 BC u_x Loss:  122.79791259765625
# AC PDE Loss:  0.0003381039132364094 	adaptive PDE Loss:  0.004177593160420656
#
#
# Current End Time: 0.6 Current Learning Rate:  0.001
#
# Iteration: 1 	Total Loss: tensor(115.6606)
# 	IC Loss:  4.2084772644557233e-07 	 BC u Loss:  4.607290611602366e-05 	 BC u_x Loss:  115.65918731689453
# AC PDE Loss:  0.0009543889900669456 	adaptive PDE Loss:  0.010868502780795097
#
# Iteration: 2 	Total Loss: tensor(78.7986)
# 	IC Loss:  1.221995353262173e-05 	 BC u Loss:  0.0005202859756536782 	 BC u_x Loss:  78.78500366210938
# AC PDE Loss:  0.0008831939776428044 	adaptive PDE Loss:  0.010201722383499146
#
# Iteration: 4 	Total Loss: tensor(99.0651)
# 	IC Loss:  0.00028848357032984495 	 BC u Loss:  0.0013054248411208391 	 BC u_x Loss:  98.7741928100586
# AC PDE Loss:  0.001163001754321158 	adaptive PDE Loss:  0.014361553825438023
#
# Iteration: 6 	Total Loss: tensor(99.3386)
# 	IC Loss:  8.020986570045352e-05 	 BC u Loss:  0.00020836919429711998 	 BC u_x Loss:  99.2573471069336
# AC PDE Loss:  0.0008567087352275848 	adaptive PDE Loss:  0.011393874883651733
#
# Iteration: 8 	Total Loss: tensor(91.3827)
# 	IC Loss:  3.0286375476862304e-05 	 BC u Loss:  1.8268356143380515e-05 	 BC u_x Loss:  91.35173797607422
# AC PDE Loss:  0.0006229105056263506 	adaptive PDE Loss:  0.010759816505014896
#
# Iteration: 10 	Total Loss: tensor(84.6345)
# 	IC Loss:  1.394153787259711e-05 	 BC u Loss:  0.0003781217092182487 	 BC u_x Loss:  84.61953735351562
# AC PDE Loss:  0.0006848035263828933 	adaptive PDE Loss:  0.008930567651987076
#
# Iteration: 12 	Total Loss: tensor(96.4705)
# 	IC Loss:  8.063061045504583e-07 	 BC u Loss:  2.7585045245359652e-05 	 BC u_x Loss:  96.46912384033203
# AC PDE Loss:  0.0005141497822478414 	adaptive PDE Loss:  0.00866642314940691
#
# Iteration: 14 	Total Loss: tensor(117.3649)
# 	IC Loss:  3.731419565156102e-05 	 BC u Loss:  0.0008999865385703743 	 BC u_x Loss:  117.32600402832031
# AC PDE Loss:  0.0007186527946032584 	adaptive PDE Loss:  0.009821102023124695
#
# Iteration: 16 	Total Loss: tensor(107.5219)
# 	IC Loss:  1.4721428669872694e-05 	 BC u Loss:  4.089956928510219e-05 	 BC u_x Loss:  107.50638580322266
# AC PDE Loss:  0.0007347349892370403 	adaptive PDE Loss:  0.008210578002035618
#
# Iteration: 18 	Total Loss: tensor(18.7184)
# 	IC Loss:  7.64945752962376e-07 	 BC u Loss:  9.221060463460162e-05 	 BC u_x Loss:  18.71483612060547
# AC PDE Loss:  0.0026949970051646233 	adaptive PDE Loss:  0.03391396999359131
#
# Iteration: 20 	Total Loss: tensor(12.3200)
# 	IC Loss:  1.6921616179388366e-06 	 BC u Loss:  0.00017597433179616928 	 BC u_x Loss:  12.316951751708984
# AC PDE Loss:  0.001189249218441546 	adaptive PDE Loss:  0.01302263792604208
#
# Iteration: 22 	Total Loss: tensor(93.1118)
# 	IC Loss:  6.598644404220977e-07 	 BC u Loss:  1.3376910828810651e-05 	 BC u_x Loss:  93.1100845336914
# AC PDE Loss:  0.0010802046163007617 	adaptive PDE Loss:  0.012755434960126877
#
# Iteration: 24 	Total Loss: tensor(117.4805)
# 	IC Loss:  1.0793341971293557e-05 	 BC u Loss:  0.0004333728284109384 	 BC u_x Loss:  117.46844482421875
# AC PDE Loss:  0.0008285020012408495 	adaptive PDE Loss:  0.012547213584184647
#
# Iteration: 26 	Total Loss: tensor(120.8266)
# 	IC Loss:  4.395998530526413e-06 	 BC u Loss:  4.72020183224231e-05 	 BC u_x Loss:  120.82142639160156
# AC PDE Loss:  0.0007298896089196205 	adaptive PDE Loss:  0.012223017401993275
#
# Iteration: 28 	Total Loss: tensor(110.1752)
# 	IC Loss:  1.4530452972394414e-05 	 BC u Loss:  0.00011706149234669283 	 BC u_x Loss:  110.15986633300781
# AC PDE Loss:  0.0006812511128373444 	adaptive PDE Loss:  0.009234870783984661
#
# Iteration: 30 	Total Loss: tensor(146.9425)
# 	IC Loss:  4.960234582540579e-05 	 BC u Loss:  1.639030597289093e-05 	 BC u_x Loss:  146.8922119140625
# AC PDE Loss:  0.0006771479966118932 	adaptive PDE Loss:  0.00846773013472557
#
# Iteration: 32 	Total Loss: tensor(129.6788)
# 	IC Loss:  1.775077726051677e-05 	 BC u Loss:  2.411340392427519e-05 	 BC u_x Loss:  129.6604766845703
# AC PDE Loss:  0.0005506750312633812 	adaptive PDE Loss:  0.007915852591395378
#
# Iteration: 34 	Total Loss: tensor(167.5873)
# 	IC Loss:  1.0955735888273921e-05 	 BC u Loss:  0.00017808917618822306 	 BC u_x Loss:  167.57577514648438
# AC PDE Loss:  0.0004085486871190369 	adaptive PDE Loss:  0.00857185572385788
#
# Iteration: 36 	Total Loss: tensor(202.6514)
# 	IC Loss:  6.827121410424297e-07 	 BC u Loss:  1.936077023856342e-05 	 BC u_x Loss:  202.64988708496094
# AC PDE Loss:  0.0007958115311339498 	adaptive PDE Loss:  0.010547959245741367
#
# Iteration: 38 	Total Loss: tensor(198.8853)
# 	IC Loss:  0.0001398035092279315 	 BC u Loss:  0.00011148888006573543 	 BC u_x Loss:  198.7445068359375
# AC PDE Loss:  0.0008706683292984962 	adaptive PDE Loss:  0.010410159826278687
#
# Iteration: 40 	Total Loss: tensor(166.7878)
# 	IC Loss:  0.00012212127330712974 	 BC u Loss:  2.6919960873783566e-05 	 BC u_x Loss:  166.66476440429688
# AC PDE Loss:  0.0008333769510500133 	adaptive PDE Loss:  0.008384420536458492
#
# Iteration: 42 	Total Loss: tensor(157.2367)
# 	IC Loss:  0.00012318589142523706 	 BC u Loss:  8.232624168158509e-06 	 BC u_x Loss:  157.11270141601562
# AC PDE Loss:  0.0007942831143736839 	adaptive PDE Loss:  0.009743323549628258
#
# Iteration: 44 	Total Loss: tensor(169.6884)
# 	IC Loss:  0.00011545835877768695 	 BC u Loss:  0.0009512132965028286 	 BC u_x Loss:  169.5714111328125
# AC PDE Loss:  0.0006108658853918314 	adaptive PDE Loss:  0.011089954525232315
#
# Iteration: 46 	Total Loss: tensor(140.9496)
# 	IC Loss:  2.4025634957069997e-06 	 BC u Loss:  2.046780900855083e-05 	 BC u_x Loss:  140.94671630859375
# AC PDE Loss:  0.00047817983431741595 	adaptive PDE Loss:  0.0064866263419389725
#
# Iteration: 48 	Total Loss: tensor(142.6729)
# 	IC Loss:  1.774602196746855e-06 	 BC u Loss:  2.3452326786355115e-05 	 BC u_x Loss:  142.67063903808594
# AC PDE Loss:  0.0004523827519733459 	adaptive PDE Loss:  0.008344841189682484
#
# Iteration: 50 	Total Loss: tensor(67.2016)
# 	IC Loss:  7.181154728641559e-07 	 BC u Loss:  0.00017784105148166418 	 BC u_x Loss:  67.19937133789062
# AC PDE Loss:  0.0013546583941206336 	adaptive PDE Loss:  0.01833900436758995
#
# Iteration: 52 	Total Loss: tensor(62.1908)
# 	IC Loss:  4.7484166998401633e-07 	 BC u Loss:  3.224184911232442e-05 	 BC u_x Loss:  62.18959045410156
# AC PDE Loss:  0.0006731547182425857 	adaptive PDE Loss:  0.008266442455351353
#
# Iteration: 54 	Total Loss: tensor(77.1752)
# 	IC Loss:  0.0005311711574904621 	 BC u Loss:  0.006130333058536053 	 BC u_x Loss:  76.63662719726562
# AC PDE Loss:  0.0012337197549641132 	adaptive PDE Loss:  0.015005851164460182
#
# Iteration: 56 	Total Loss: tensor(38.2845)
# 	IC Loss:  9.37256554607302e-05 	 BC u Loss:  0.0005374933825805783 	 BC u_x Loss:  38.189083099365234
# AC PDE Loss:  0.0011043130652979016 	adaptive PDE Loss:  0.01242649182677269
#
# Iteration: 58 	Total Loss: tensor(98.0264)
# 	IC Loss:  8.328442163474392e-06 	 BC u Loss:  0.00019216309010516852 	 BC u_x Loss:  98.01744842529297
# AC PDE Loss:  0.0004606182628776878 	adaptive PDE Loss:  0.006664087995886803
#
# Iteration: 60 	Total Loss: tensor(102.0779)
# 	IC Loss:  8.18353146314621e-06 	 BC u Loss:  1.642349707253743e-05 	 BC u_x Loss:  102.06929016113281
# AC PDE Loss:  0.0004406394436955452 	adaptive PDE Loss:  0.007041024509817362
#
# Iteration: 62 	Total Loss: tensor(89.3946)
# 	IC Loss:  9.72215821093414e-06 	 BC u Loss:  0.00010434540308779106 	 BC u_x Loss:  89.38423919677734
# AC PDE Loss:  0.0004952368326485157 	adaptive PDE Loss:  0.007406438235193491
#
# Iteration: 64 	Total Loss: tensor(124.8781)
# 	IC Loss:  0.000810255587566644 	 BC u Loss:  0.0022863573394715786 	 BC u_x Loss:  124.06401062011719
# AC PDE Loss:  0.001563271158374846 	adaptive PDE Loss:  0.01829676702618599
#
# Iteration: 66 	Total Loss: tensor(107.8655)
# 	IC Loss:  6.420688441721722e-05 	 BC u Loss:  5.8448047639103606e-05 	 BC u_x Loss:  107.80068969726562
# AC PDE Loss:  0.000496698368806392 	adaptive PDE Loss:  0.007787120528519154
#
# Iteration: 68 	Total Loss: tensor(96.5315)
# 	IC Loss:  9.288493743042636e-07 	 BC u Loss:  2.6145859010284767e-05 	 BC u_x Loss:  96.52947998046875
# AC PDE Loss:  0.0010349515359848738 	adaptive PDE Loss:  0.01310848817229271
#
# Iteration: 70 	Total Loss: tensor(135.8149)
# 	IC Loss:  5.142419468029402e-07 	 BC u Loss:  1.5168047866609413e-05 	 BC u_x Loss:  135.81405639648438
# AC PDE Loss:  0.0003114540595561266 	adaptive PDE Loss:  0.005303956568241119
#
# Iteration: 72 	Total Loss: tensor(162.2150)
# 	IC Loss:  2.2954125142859994e-06 	 BC u Loss:  1.3956333532405552e-05 	 BC u_x Loss:  162.2122802734375
# AC PDE Loss:  0.0003708096919581294 	adaptive PDE Loss:  0.008469576016068459
#
# Iteration: 74 	Total Loss: tensor(156.4350)
# 	IC Loss:  7.871673005865887e-05 	 BC u Loss:  0.00012574970605783165 	 BC u_x Loss:  156.3556671142578
# AC PDE Loss:  0.0005131560028530657 	adaptive PDE Loss:  0.007155964151024818
#
# Iteration: 76 	Total Loss: tensor(176.4053)
# 	IC Loss:  1.5897213643256691e-06 	 BC u Loss:  6.414251402020454e-05 	 BC u_x Loss:  176.4033203125
# AC PDE Loss:  0.00034300421248190105 	adaptive PDE Loss:  0.005844444036483765
#
# Iteration: 78 	Total Loss: tensor(130.0226)
# 	IC Loss:  7.463230303983437e-06 	 BC u Loss:  7.673955224163365e-06 	 BC u_x Loss:  130.0146484375
# AC PDE Loss:  0.0004711111541837454 	adaptive PDE Loss:  0.005934118293225765
#
# Iteration: 80 	Total Loss: tensor(160.7924)
# 	IC Loss:  8.048568270169199e-05 	 BC u Loss:  0.0027215888258069754 	 BC u_x Loss:  160.70858764648438
# AC PDE Loss:  0.0006413585506379604 	adaptive PDE Loss:  0.008708310313522816
#
# Iteration: 82 	Total Loss: tensor(102.7208)
# 	IC Loss:  3.495579949230887e-05 	 BC u Loss:  0.00022995201288722456 	 BC u_x Loss:  102.68492889404297
# AC PDE Loss:  0.0006588406395167112 	adaptive PDE Loss:  0.010489175096154213
#
# Iteration: 84 	Total Loss: tensor(142.1592)
# 	IC Loss:  0.00035805636434815824 	 BC u Loss:  0.00014248517982196063 	 BC u_x Loss:  141.8000946044922
# AC PDE Loss:  0.0008974983356893063 	adaptive PDE Loss:  0.010090982541441917
#
# Iteration: 86 	Total Loss: tensor(66.9683)
# 	IC Loss:  5.600414851869573e-07 	 BC u Loss:  1.632878957025241e-05 	 BC u_x Loss:  66.96726989746094
# AC PDE Loss:  0.00043996720341965556 	adaptive PDE Loss:  0.008359638042747974
#
# Iteration: 88 	Total Loss: tensor(101.1720)
# 	IC Loss:  8.423330291407183e-05 	 BC u Loss:  0.000378031370928511 	 BC u_x Loss:  101.08690643310547
# AC PDE Loss:  0.00047444988740608096 	adaptive PDE Loss:  0.007652414031326771
#
# Iteration: 90 	Total Loss: tensor(106.9412)
# 	IC Loss:  1.2823362567360164e-06 	 BC u Loss:  4.924487438984215e-05 	 BC u_x Loss:  106.93940734863281
# AC PDE Loss:  0.0004203055868856609 	adaptive PDE Loss:  0.00692578312009573
#
# Iteration: 92 	Total Loss: tensor(107.3143)
# 	IC Loss:  3.6843401176156476e-05 	 BC u Loss:  5.4687716328771785e-05 	 BC u_x Loss:  107.27681732177734
# AC PDE Loss:  0.000565500755328685 	adaptive PDE Loss:  0.008591417223215103
#
# Iteration: 94 	Total Loss: tensor(96.3726)
# 	IC Loss:  1.1506231203384232e-05 	 BC u Loss:  2.5654942874098197e-05 	 BC u_x Loss:  96.36058807373047
# AC PDE Loss:  0.0004984513507224619 	adaptive PDE Loss:  0.007653237320482731
#
# Iteration: 96 	Total Loss: tensor(120.0353)
# 	IC Loss:  5.899901225348003e-05 	 BC u Loss:  0.00010806758655235171 	 BC u_x Loss:  119.97555541992188
# AC PDE Loss:  0.0006729408050887287 	adaptive PDE Loss:  0.012617193162441254
#
# Iteration: 98 	Total Loss: tensor(155.8441)
# 	IC Loss:  6.101959661464207e-05 	 BC u Loss:  0.0050939093343913555 	 BC u_x Loss:  155.7775421142578
# AC PDE Loss:  0.0004304409958422184 	adaptive PDE Loss:  0.006686263717710972
#
#
# Current End Time: 0.7 Current Learning Rate:  0.001
#
# Iteration: 1 	Total Loss: tensor(12.2269)
# 	IC Loss:  9.690903652881389e-07 	 BC u Loss:  7.284761522896588e-05 	 BC u_x Loss:  12.221920013427734
# AC PDE Loss:  0.003951064310967922 	adaptive PDE Loss:  0.0438346303999424
#
# Iteration: 2 	Total Loss: tensor(13.8397)
# 	IC Loss:  7.685050150030293e-06 	 BC u Loss:  0.002626185305416584 	 BC u_x Loss:  13.827232360839844
# AC PDE Loss:  0.002130206674337387 	adaptive PDE Loss:  0.032312989234924316
#
# Iteration: 4 	Total Loss: tensor(13.6367)
# 	IC Loss:  6.010544097989623e-07 	 BC u Loss:  5.5710366723360494e-05 	 BC u_x Loss:  13.634490013122559
# AC PDE Loss:  0.0015794869977980852 	adaptive PDE Loss:  0.019905317574739456
#
# Iteration: 6 	Total Loss: tensor(10.1631)
# 	IC Loss:  1.3964036043034866e-06 	 BC u Loss:  0.0001427456154488027 	 BC u_x Loss:  10.160656929016113
# AC PDE Loss:  0.000930537236854434 	adaptive PDE Loss:  0.018964262679219246
#
# Iteration: 8 	Total Loss: tensor(11.4318)
# 	IC Loss:  2.0381712602102198e-06 	 BC u Loss:  0.00010394564742455259 	 BC u_x Loss:  11.428827285766602
# AC PDE Loss:  0.0008650579256936908 	adaptive PDE Loss:  0.011896895244717598
#
# Iteration: 10 	Total Loss: tensor(30.3212)
# 	IC Loss:  1.7584356100996956e-05 	 BC u Loss:  5.5511620303150266e-05 	 BC u_x Loss:  30.302732467651367
# AC PDE Loss:  0.000876700971275568 	adaptive PDE Loss:  0.01190280169248581
#
# Iteration: 12 	Total Loss: tensor(43.3358)
# 	IC Loss:  5.0161706894868985e-06 	 BC u Loss:  0.0002590216463431716 	 BC u_x Loss:  43.32984924316406
# AC PDE Loss:  0.0006842395523563027 	adaptive PDE Loss:  0.011535064317286015
#
# Iteration: 14 	Total Loss: tensor(49.9337)
# 	IC Loss:  9.821947060117964e-06 	 BC u Loss:  2.1668485715053976e-05 	 BC u_x Loss:  49.9232292175293
# AC PDE Loss:  0.0006514218403026462 	adaptive PDE Loss:  0.010357367806136608
#
# Iteration: 16 	Total Loss: tensor(58.6971)
# 	IC Loss:  4.325297595642041e-06 	 BC u Loss:  0.0001796293508959934 	 BC u_x Loss:  58.69192886352539
# AC PDE Loss:  0.000647973211016506 	adaptive PDE Loss:  0.008497558534145355
#
# Iteration: 18 	Total Loss: tensor(49.2090)
# 	IC Loss:  4.349208666099003e-06 	 BC u Loss:  0.0002332790318178013 	 BC u_x Loss:  49.203887939453125
# AC PDE Loss:  0.0005795088363811374 	adaptive PDE Loss:  0.010925501585006714
#
# ...
#
# Iteration: 62 	Total Loss: tensor(351.6604)
# 	IC Loss:  0.00077151192817837 	 BC u Loss:  0.000775710737798363 	 BC u_x Loss:  350.8862609863281
# AC PDE Loss:  0.001845775987021625 	adaptive PDE Loss:  0.02371843531727791
#
# Iteration: 64 	Total Loss: tensor(485.9801)
# 	IC Loss:  0.00014809328422416002 	 BC u Loss:  1.9858225641655736e-05 	 BC u_x Loss:  485.8311462402344
# AC PDE Loss:  0.0007928450359031558 	adaptive PDE Loss:  0.017135391011834145
#
# Iteration: 66 	Total Loss: tensor(484.9065)
# 	IC Loss:  8.902769081942097e-07 	 BC u Loss:  1.2126410183554981e-05 	 BC u_x Loss:  484.9052734375
# AC PDE Loss:  0.0003410347562748939 	adaptive PDE Loss:  0.021509861573576927
#
# Iteration: 68 	Total Loss: tensor(311.2498)
# 	IC Loss:  6.788589962525293e-05 	 BC u Loss:  0.006854200270026922 	 BC u_x Loss:  311.1732177734375
# AC PDE Loss:  0.0018874113447964191 	adaptive PDE Loss:  0.042371492832899094
#
# Iteration: 70 	Total Loss: tensor(618.9559)
# 	IC Loss:  2.0321964257163927e-05 	 BC u Loss:  0.00010285465396009386 	 BC u_x Loss:  618.9349975585938
# AC PDE Loss:  0.0004849718534387648 	adaptive PDE Loss:  0.011749567463994026
#
# Iteration: 72 	Total Loss: tensor(48.3053)
# 	IC Loss:  0.001756679848767817 	 BC u Loss:  0.0003106932854279876 	 BC u_x Loss:  46.53120422363281
# AC PDE Loss:  0.017131585627794266 	adaptive PDE Loss:  0.1846374273300171
#
# Iteration: 74 	Total Loss: tensor(765.5135)
# 	IC Loss:  3.415613036850118e-07 	 BC u Loss:  2.8042848498444073e-05 	 BC u_x Loss:  765.5127563476562
# AC PDE Loss:  0.00037196543416939676 	adaptive PDE Loss:  0.017865413799881935
#
# Iteration: 76 	Total Loss: tensor(794.8979)
# 	IC Loss:  4.6755098992434796e-07 	 BC u Loss:  3.497983198030852e-05 	 BC u_x Loss:  794.8970336914062
# AC PDE Loss:  0.0002914631913881749 	adaptive PDE Loss:  0.018078895285725594
#
# Iteration: 78 	Total Loss: tensor(705.2173)
# 	IC Loss:  3.354533419042127e-06 	 BC u Loss:  4.494385211728513e-05 	 BC u_x Loss:  705.2135009765625
# AC PDE Loss:  0.00035849286359734833 	adaptive PDE Loss:  0.041193656623363495
#
# Iteration: 80 	Total Loss: tensor(559.4203)
# 	IC Loss:  8.100405830191448e-05 	 BC u Loss:  0.0007702787406742573 	 BC u_x Loss:  559.3380737304688
# AC PDE Loss:  0.000509613542817533 	adaptive PDE Loss:  0.01926588825881481
#
# Iteration: 82 	Total Loss: tensor(588.4481)
# 	IC Loss:  0.0004942223895341158 	 BC u Loss:  0.0014393541496247053 	 BC u_x Loss:  587.951171875
# AC PDE Loss:  0.001296553062275052 	adaptive PDE Loss:  0.06816606223583221
#
# Iteration: 84 	Total Loss: tensor(497.3398)
# 	IC Loss:  7.741533045191318e-05 	 BC u Loss:  0.00043687556171789765 	 BC u_x Loss:  497.2613525390625
# AC PDE Loss:  0.0005463508423417807 	adaptive PDE Loss:  0.05786354839801788
#
# Iteration: 86 	Total Loss: tensor(637.1074)
# 	IC Loss:  3.619693984546757e-07 	 BC u Loss:  9.413971383764874e-06 	 BC u_x Loss:  637.1066284179688
# AC PDE Loss:  0.0003450964286457747 	adaptive PDE Loss:  0.022435501217842102
#
# Iteration: 88 	Total Loss: tensor(593.6400)
# 	IC Loss:  4.547781372821191e-06 	 BC u Loss:  4.8788253479870036e-05 	 BC u_x Loss:  593.6347045898438
# AC PDE Loss:  0.0005830401787534356 	adaptive PDE Loss:  0.012829577550292015
#
# Iteration: 90 	Total Loss: tensor(532.0343)
# 	IC Loss:  4.7489626808783214e-07 	 BC u Loss:  1.7742844647727907e-05 	 BC u_x Loss:  532.0335693359375
# AC PDE Loss:  0.00022118525521364063 	adaptive PDE Loss:  0.019292175769805908
#
# Iteration: 92 	Total Loss: tensor(523.6986)
# 	IC Loss:  5.4895754146855325e-06 	 BC u Loss:  4.1103157855104655e-05 	 BC u_x Loss:  523.6927490234375
# AC PDE Loss:  0.00033363798866048455 	adaptive PDE Loss:  0.08232942968606949
#
# Iteration: 94 	Total Loss: tensor(529.9445)
# 	IC Loss:  2.5200197342201136e-06 	 BC u Loss:  1.9671088011818938e-05 	 BC u_x Loss:  529.9417114257812
# AC PDE Loss:  0.0002430329768685624 	adaptive PDE Loss:  0.032262761145830154
#
# Iteration: 96 	Total Loss: tensor(551.1480)
# 	IC Loss:  7.077366717567202e-06 	 BC u Loss:  6.595821469090879e-05 	 BC u_x Loss:  551.140625
# AC PDE Loss:  0.0002481189731042832 	adaptive PDE Loss:  0.06618621200323105
#
# Iteration: 98 	Total Loss: tensor(571.7999)
# 	IC Loss:  0.00020317177404649556 	 BC u Loss:  0.00011651558452285826 	 BC u_x Loss:  571.5961303710938
# AC PDE Loss:  0.0005123686860315502 	adaptive PDE Loss:  0.7317542433738708
#
#
# Current End Time: 1.0 Current Learning Rate:  0.001
#
# Iteration: 1 	Total Loss: tensor(311.1086)
# 	IC Loss:  4.587306193570839e-06 	 BC u Loss:  8.120805432554334e-06 	 BC u_x Loss:  311.1036682128906
# AC PDE Loss:  0.00038072909228503704 	adaptive PDE Loss:  0.06087569147348404
#
# Iteration: 2 	Total Loss: tensor(165.2150)
# 	IC Loss:  7.065909812808968e-07 	 BC u Loss:  1.9280481865280308e-05 	 BC u_x Loss:  165.21339416503906
# AC PDE Loss:  0.0008525692974217236 	adaptive PDE Loss:  1.1587823629379272
#
# Iteration: 4 	Total Loss: tensor(508.4785)
# 	IC Loss:  2.804344694595784e-05 	 BC u Loss:  0.0011052488116547465 	 BC u_x Loss:  508.4488525390625
# AC PDE Loss:  0.0005334326415322721 	adaptive PDE Loss:  0.654421329498291
#
# Iteration: 6 	Total Loss: tensor(544.4594)
# 	IC Loss:  9.018684067996219e-06 	 BC u Loss:  8.645297930343077e-05 	 BC u_x Loss:  544.4498291015625
# AC PDE Loss:  0.0004495667526498437 	adaptive PDE Loss:  0.1404063105583191
#
# Iteration: 8 	Total Loss: tensor(286.3873)
# 	IC Loss:  0.00011415003245929256 	 BC u Loss:  0.0007923736702650785 	 BC u_x Loss:  286.2712097167969
# AC PDE Loss:  0.0011894595809280872 	adaptive PDE Loss:  0.02317320555448532
#
# Iteration: 10 	Total Loss: tensor(472.0878)
# 	IC Loss:  3.787358991758083e-06 	 BC u Loss:  6.427567859645933e-05 	 BC u_x Loss:  472.0834655761719
# AC PDE Loss:  0.0005334888701327145 	adaptive PDE Loss:  0.020115956664085388
#
# Iteration: 12 	Total Loss: tensor(362.3441)
# 	IC Loss:  2.7919963940803427e-06 	 BC u Loss:  3.5315788409207016e-05 	 BC u_x Loss:  362.3409423828125
# AC PDE Loss:  0.00039275840390473604 	adaptive PDE Loss:  0.17567454278469086
#
# Iteration: 14 	Total Loss: tensor(568.8348)
# 	IC Loss:  0.0002616330748423934 	 BC u Loss:  0.0004898335901089013 	 BC u_x Loss:  568.5714111328125
# AC PDE Loss:  0.001270597567781806 	adaptive PDE Loss:  0.030010363087058067
#
# Iteration: 16 	Total Loss: tensor(370.5654)
# 	IC Loss:  9.185066301142797e-05 	 BC u Loss:  0.0017895858036354184 	 BC u_x Loss:  370.4708557128906
# AC PDE Loss:  0.0008673028205521405 	adaptive PDE Loss:  0.010454844683408737
#
# Iteration: 18 	Total Loss: tensor(603.2897)
# 	IC Loss:  5.515651355381124e-05 	 BC u Loss:  1.836917181208264e-05 	 BC u_x Loss:  603.2337036132812
# AC PDE Loss:  0.0007708537741564214 	adaptive PDE Loss:  0.017037268728017807
#
# Iteration: 20 	Total Loss: tensor(861.9775)
# 	IC Loss:  4.2523839738350944e-07 	 BC u Loss:  2.1962314349366352e-05 	 BC u_x Loss:  861.9763793945312
# AC PDE Loss:  0.0007250215276144445 	adaptive PDE Loss:  0.02003139816224575
#
# Iteration: 22 	Total Loss: tensor(783.3029)
# 	IC Loss:  2.3415771011059405e-06 	 BC u Loss:  0.0002371000882703811 	 BC u_x Loss:  783.2998657226562
# AC PDE Loss:  0.0005127530312165618 	adaptive PDE Loss:  0.013114805333316326
#
# Iteration: 24 	Total Loss: tensor(1203.2234)
# 	IC Loss:  2.268904609081801e-06 	 BC u Loss:  0.00041202909778803587 	 BC u_x Loss:  1203.2200927734375
# AC PDE Loss:  0.0006100534228608012 	adaptive PDE Loss:  0.013299444690346718
#
# Iteration: 26 	Total Loss: tensor(911.0933)
# 	IC Loss:  1.3983643839310389e-05 	 BC u Loss:  0.00016055205196607858 	 BC u_x Loss:  911.0787353515625
# AC PDE Loss:  0.00034384889295324683 	adaptive PDE Loss:  0.010037658736109734
#
# Iteration: 28 	Total Loss: tensor(433.6040)
# 	IC Loss:  3.393706356291659e-05 	 BC u Loss:  9.758114902069792e-05 	 BC u_x Loss:  433.5694885253906
# AC PDE Loss:  0.00047978400834836066 	adaptive PDE Loss:  0.15015506744384766
#
# Iteration: 30 	Total Loss: tensor(391.9381)
# 	IC Loss:  1.4574571650882717e-05 	 BC u Loss:  0.00013033272989559919 	 BC u_x Loss:  391.9228515625
# AC PDE Loss:  0.0005904589779675007 	adaptive PDE Loss:  0.022248439490795135
#
# Iteration: 32 	Total Loss: tensor(546.0139)
# 	IC Loss:  2.856019818864297e-06 	 BC u Loss:  5.3537714848062024e-05 	 BC u_x Loss:  546.0106811523438
# AC PDE Loss:  0.0003228222776670009 	adaptive PDE Loss:  0.1702652871608734
#
# Iteration: 34 	Total Loss: tensor(692.4646)
# 	IC Loss:  1.8552877008914948e-05 	 BC u Loss:  0.00021630115224979818 	 BC u_x Loss:  692.4452514648438
# AC PDE Loss:  0.0005336788017302752 	adaptive PDE Loss:  0.043993979692459106
#
# Iteration: 36 	Total Loss: tensor(887.4641)
# 	IC Loss:  3.5379218843445415e-07 	 BC u Loss:  1.0062482033390552e-05 	 BC u_x Loss:  887.46337890625
# AC PDE Loss:  0.00035518890945240855 	adaptive PDE Loss:  0.19492384791374207
#
# Iteration: 38 	Total Loss: tensor(982.0369)
# 	IC Loss:  5.460223633235728e-07 	 BC u Loss:  2.972551556013059e-05 	 BC u_x Loss:  982.0360717773438
# AC PDE Loss:  0.0003184832166880369 	adaptive PDE Loss:  0.009996430017054081
#
# Iteration: 40 	Total Loss: tensor(692.3646)
# 	IC Loss:  3.214718390154303e-06 	 BC u Loss:  7.814267883077264e-05 	 BC u_x Loss:  692.3610229492188
# AC PDE Loss:  0.0002844595583155751 	adaptive PDE Loss:  0.049361031502485275
#
# Iteration: 42 	Total Loss: tensor(620.5316)
# 	IC Loss:  5.526122777155251e-07 	 BC u Loss:  1.9031029296456836e-05 	 BC u_x Loss:  620.53076171875
# AC PDE Loss:  0.00024852523347362876 	adaptive PDE Loss:  0.715104877948761
#
# Iteration: 44 	Total Loss: tensor(805.0372)
# 	IC Loss:  5.345426870917436e-06 	 BC u Loss:  2.7700300051947124e-05 	 BC u_x Loss:  805.0314331054688
# AC PDE Loss:  0.0003562311176210642 	adaptive PDE Loss:  0.03629765659570694
#
# Iteration: 46 	Total Loss: tensor(574.7297)
# 	IC Loss:  3.5125610793329543e-06 	 BC u Loss:  2.024107197939884e-05 	 BC u_x Loss:  574.725830078125
# AC PDE Loss:  0.00033352235914207995 	adaptive PDE Loss:  0.14929145574569702
#
# Iteration: 48 	Total Loss: tensor(703.4700)
# 	IC Loss:  0.000160983792738989 	 BC u Loss:  0.0007399455644190311 	 BC u_x Loss:  703.3077392578125
# AC PDE Loss:  0.0005278345779515803 	adaptive PDE Loss:  0.019843004643917084
#
# Iteration: 50 	Total Loss: tensor(423.8226)
# 	IC Loss:  7.274425115610939e-07 	 BC u Loss:  2.4753957404755056e-05 	 BC u_x Loss:  423.8216857910156
# AC PDE Loss:  0.00018710526637732983 	adaptive PDE Loss:  0.01026560552418232
#
# Iteration: 52 	Total Loss: tensor(1165.3121)
# 	IC Loss:  6.550889679601823e-07 	 BC u Loss:  0.00019963223894592375 	 BC u_x Loss:  1165.310302734375
# AC PDE Loss:  0.0010007150704041123 	adaptive PDE Loss:  0.03135782107710838
#
# Iteration: 54 	Total Loss: tensor(914.3395)
# 	IC Loss:  3.6048254514753353e-07 	 BC u Loss:  3.488568472675979e-05 	 BC u_x Loss:  914.338623046875
# AC PDE Loss:  0.0004663105355575681 	adaptive PDE Loss:  0.024400753900408745
#
# Iteration: 56 	Total Loss: tensor(831.4695)
# 	IC Loss:  4.155430701757723e-07 	 BC u Loss:  1.4490515241050161e-05 	 BC u_x Loss:  831.4685668945312
# AC PDE Loss:  0.00048631266690790653 	adaptive PDE Loss:  0.013593088835477829
#
# Iteration: 58 	Total Loss: tensor(928.8228)
# 	IC Loss:  3.3106343835243024e-06 	 BC u Loss:  4.33595159847755e-05 	 BC u_x Loss:  928.8189697265625
# AC PDE Loss:  0.0005124553572386503 	adaptive PDE Loss:  0.009514257311820984
#
# Iteration: 60 	Total Loss: tensor(486.5894)
# 	IC Loss:  2.2990208890405484e-05 	 BC u Loss:  5.691586557077244e-05 	 BC u_x Loss:  486.5658874511719
# AC PDE Loss:  0.0004874670412391424 	adaptive PDE Loss:  0.15176153182983398
#
# Iteration: 62 	Total Loss: tensor(598.0288)
# 	IC Loss:  0.00027995818527415395 	 BC u Loss:  3.927678699255921e-05 	 BC u_x Loss:  597.7479858398438
# AC PDE Loss:  0.0007654292276129127 	adaptive PDE Loss:  0.01835392415523529
#
# Iteration: 64 	Total Loss: tensor(593.0618)
# 	IC Loss:  8.01689166110009e-05 	 BC u Loss:  1.264734055439476e-05 	 BC u_x Loss:  592.981201171875
# AC PDE Loss:  0.00041356630390509963 	adaptive PDE Loss:  0.076675646007061
#
# Iteration: 66 	Total Loss: tensor(393.0187)
# 	IC Loss:  5.278548997011967e-05 	 BC u Loss:  0.0010981495724990964 	 BC u_x Loss:  392.96429443359375
# AC PDE Loss:  0.0004897941835224628 	adaptive PDE Loss:  0.014237955212593079
#
# Iteration: 68 	Total Loss: tensor(723.4647)
# 	IC Loss:  4.20539322476543e-07 	 BC u Loss:  1.2749552297464106e-05 	 BC u_x Loss:  723.4634399414062
# AC PDE Loss:  0.0008117027464322746 	adaptive PDE Loss:  0.029712451621890068
#
# Iteration: 70 	Total Loss: tensor(1097.0061)
# 	IC Loss:  4.285902468836866e-05 	 BC u Loss:  0.0011202305322512984 	 BC u_x Loss:  1096.9617919921875
# AC PDE Loss:  0.0003566535597201437 	adaptive PDE Loss:  0.01720874197781086
#
# Iteration: 72 	Total Loss: tensor(833.1320)
# 	IC Loss:  1.1150518730573822e-06 	 BC u Loss:  2.659123856574297e-05 	 BC u_x Loss:  833.1304931640625
# AC PDE Loss:  0.0003752645861823112 	adaptive PDE Loss:  0.03365345299243927
#
# Iteration: 74 	Total Loss: tensor(899.0565)
# 	IC Loss:  4.052272288390668e-06 	 BC u Loss:  0.00015994854038581252 	 BC u_x Loss:  899.052001953125
# AC PDE Loss:  0.00032425764948129654 	adaptive PDE Loss:  0.03111971914768219
#
# Iteration: 76 	Total Loss: tensor(747.7493)
# 	IC Loss:  4.445351748927351e-07 	 BC u Loss:  2.7388572561903857e-05 	 BC u_x Loss:  747.7486572265625
# AC PDE Loss:  0.0002232731058029458 	adaptive PDE Loss:  0.3410007953643799
#
# Iteration: 78 	Total Loss: tensor(635.7754)
# 	IC Loss:  2.2726942916051485e-05 	 BC u Loss:  2.3022370442049578e-05 	 BC u_x Loss:  635.7523803710938
# AC PDE Loss:  0.0002811223384924233 	adaptive PDE Loss:  0.13753491640090942
#
# Iteration: 80 	Total Loss: tensor(695.7128)
# 	IC Loss:  1.5477745591852e-06 	 BC u Loss:  4.092483868589625e-05 	 BC u_x Loss:  695.7086181640625
# AC PDE Loss:  0.002536807442083955 	adaptive PDE Loss:  0.054536353796720505
#
# Iteration: 82 	Total Loss: tensor(1169.8383)
# 	IC Loss:  6.199759923219972e-07 	 BC u Loss:  2.0713796402560547e-05 	 BC u_x Loss:  1169.8369140625
# AC PDE Loss:  0.0007356296409852803 	adaptive PDE Loss:  0.01497049443423748
#
# Iteration: 84 	Total Loss: tensor(1031.4309)
# 	IC Loss:  5.532247087103315e-07 	 BC u Loss:  1.4649973309133202e-05 	 BC u_x Loss:  1031.4298095703125
# AC PDE Loss:  0.0004782715695910156 	adaptive PDE Loss:  0.10365062952041626
#
# Iteration: 86 	Total Loss: tensor(1121.5056)
# 	IC Loss:  1.0825380059031886e-06 	 BC u Loss:  4.083271778654307e-05 	 BC u_x Loss:  1121.5040283203125
# AC PDE Loss:  0.0004757592105306685 	adaptive PDE Loss:  0.14341163635253906
#
# Iteration: 88 	Total Loss: tensor(1160.3250)
# 	IC Loss:  0.00014226713392417878 	 BC u Loss:  0.00037001946475356817 	 BC u_x Loss:  1160.181640625
# AC PDE Loss:  0.0007882557110860944 	adaptive PDE Loss:  0.025058435276150703
#
# Iteration: 90 	Total Loss: tensor(661.0568)
# 	IC Loss:  0.0005655274144373834 	 BC u Loss:  0.0006714279297739267 	 BC u_x Loss:  660.4891967773438
# AC PDE Loss:  0.0014258954906836152 	adaptive PDE Loss:  0.04330500215291977
#
# Iteration: 92 	Total Loss: tensor(680.7109)
# 	IC Loss:  6.153924800855748e-07 	 BC u Loss:  6.976288204896264e-06 	 BC u_x Loss:  680.7100219726562
# AC PDE Loss:  0.00027482956647872925 	adaptive PDE Loss:  0.006889747455716133
#
# Iteration: 94 	Total Loss: tensor(488.3406)
# 	IC Loss:  9.629414307710249e-06 	 BC u Loss:  1.7532025594846345e-05 	 BC u_x Loss:  488.3306884765625
# AC PDE Loss:  0.0002858582593034953 	adaptive PDE Loss:  0.0348932147026062
#
# Iteration: 96 	Total Loss: tensor(589.5690)
# 	IC Loss:  0.0006683439714834094 	 BC u Loss:  7.872554124332964e-05 	 BC u_x Loss:  588.8990478515625
# AC PDE Loss:  0.0014965200098231435 	adaptive PDE Loss:  0.5405060648918152
#
# Iteration: 98 	Total Loss: tensor(584.0770)
# 	IC Loss:  4.97740586524742e-07 	 BC u Loss:  9.858601515588816e-06 	 BC u_x Loss:  584.0763549804688
# AC PDE Loss:  0.00019061278726439923 	adaptive PDE Loss:  0.02476406842470169
#
#
# Training Pass 2
#
#
# Current End Time: 1.0 Current Learning Rate:  0.0001
#
#
# Training Pass 3
#
#
# Current End Time: 1.0 Current Learning Rate:  0.0001
# Total Time:	 177964.30184817314
# Pass 1 Time:	 177964.29267406464
# Pass 2 Time:	 0.005615949630737305
# Pass 3 Time:	 0.0035581588745117188
